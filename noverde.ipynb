# %% [markdown]
# # Data Engineering Technical Test

# %% [markdown]
# Versão do spark:

# %%
sc.version
# Out:
# u'2.4.4'

# %% [markdown]
# ## Carregando arquivos de entrada

# %%
payments_sample = spark.read.parquet("input/payments_sample.parquet")

# %%
installments_sample = spark.read.json("input/installments_sample.json")

# %%
loans_sample = spark.read.csv("input/loans_sample.csv",header=True, inferSchema=True)

# %% [markdown]
# ## Análise dos dados de entrada

# %% [markdown]
# Iniciarei a análise dos dados pelo dataframe payments_sample

# %%
payments_sample.printSchema()
# Out:
# root
#  |-- loan_id: long (nullable = true)
#  |-- payment_date: date (nullable = true)
#  |-- payment_method: string (nullable = true)
#  |-- payment_id: string (nullable = true)
#  |-- paid_amount: double (nullable = true)

# %%
payments_sample.show()
# Out:
# +-------+------------+--------------+--------------------+-----------+
# |loan_id|payment_date|payment_method|          payment_id|paid_amount|
# +-------+------------+--------------+--------------------+-----------+
# |    291|  2017-05-30|           ted|ed5a489a-bb07-456...|     547.92|
# |    291|  2017-06-26|    creditcard|7abaf860-9632-40e...|     547.92|
# |    291|  2017-08-13|    creditcard|e659b8d6-8d7d-48f...|     557.92|
# |    291|  2017-10-17|           ted|4f0566cb-c9ef-451...|     552.92|
# |    291|  2017-09-11|           ted|8c017813-1df5-459...|     547.92|
# |    291|  2018-05-19|    creditcard|9149225e-3d63-4b6...|     570.92|
# |    291|  2017-12-09|    creditcard|37f2896e-8d9c-49c...|     547.92|
# |    291|  2017-11-04|    creditcard|3caab925-de5a-47f...|     547.92|
# |    291|  2018-02-06|    creditcard|7c70cef2-4fc5-4bf...|     547.92|
# |    291|  2018-03-26|    creditcard|bf207cf6-6d4f-414...|     547.92|
# |    291|  2018-01-09|           ted|3b1d333c-d47e-45c...|     547.92|
# |    291|  2018-03-18|        boleto|4f2497ed-7a3a-438...|     585.92|
# |    670|  2017-08-20|           ted|439ba70a-c831-4ec...|     389.57|
# |    154|  2017-08-26|    creditcard|0f01564e-9d5c-4e3...|     328.45|
# |    154|  2017-10-08|        boleto|5a78ca4e-c45f-430...|     299.45|
# |    154|  2017-11-19|        boleto|e34143b9-858a-434...|     299.45|
# |    154|  2017-12-03|    creditcard|9671587b-c1fa-4a0...|     299.45|
# |    154|  2018-01-21|    creditcard|ad3d4694-24eb-443...|     299.45|
# |    154|  2018-02-15|           ted|5e9e9576-79da-4a5...|     299.45|
# |    154|  2018-03-12|        boleto|6b8492e6-cf2f-48c...|     299.45|
# +-------+------------+--------------+--------------------+-----------+
# only showing top 20 rows

# %%
payments_sample.count()
# Out:
# 6930

# %%
print("Total de valores nulos por coluna:")
for col in payments_sample.columns:
  print(" {}={}".format(col, payments_sample.filter(payments_sample[col].isNull() ).count()) )
# Out:
# Total de valores nulos por coluna:
#  loan_id=0
#  payment_date=0
#  payment_method=0
#  payment_id=0
#  paid_amount=0

# %%
payments_sample.select("loan_id").distinct().count()
# Out:
# 775

# %% [markdown]
# O dataframe payments_sample apresenta as informações sobre os pagamentos dos emprestimos, possuindo informações como o identificador do emprestimo, data de pagamento, metódo de pagamento e valor pago. Possui 6930 registros e não possui valores nulos. Esses registros são referentes a um total de 775 emprestimos realizados.

# %%
loans_sample.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- loan_id: integer (nullable = true)
#  |-- period: integer (nullable = true)
#  |-- accepted_at: timestamp (nullable = true)
#  |-- payday: integer (nullable = true)
#  |-- interest_rate: double (nullable = true)

# %%
loans_sample.show(truncate=False)
# Out:
# +---+-------+------+-----------------------+------+-------------+
# |_c0|loan_id|period|accepted_at            |payday|interest_rate|
# +---+-------+------+-----------------------+------+-------------+
# |0  |0      |12    |2017-05-19 10:09:47.285|25    |3.12         |
# |1  |1      |12    |2017-05-18 20:27:41.197|25    |7.55         |
# |2  |2      |12    |2017-05-18 22:04:41.276|25    |7.55         |
# |3  |3      |12    |2017-05-17 23:47:24.822|5     |7.55         |
# |4  |4      |9     |2017-05-23 00:15:10.971|15    |7.49         |
# |5  |5      |12    |2017-05-19 08:42:43.162|25    |3.12         |
# |6  |6      |9     |2017-05-16 08:23:54.438|15    |7.49         |
# |7  |7      |12    |2017-05-22 17:17:49.956|5     |7.55         |
# |8  |8      |12    |2017-05-21 07:03:02.534|15    |7.55         |
# |9  |9      |12    |2017-05-23 12:33:22.614|15    |7.55         |
# |10 |10     |12    |2017-05-20 18:06:31.745|5     |7.55         |
# |11 |11     |12    |2017-05-22 13:36:45.83 |15    |7.55         |
# |12 |12     |12    |2017-05-23 03:37:12.165|15    |7.55         |
# |13 |13     |12    |2017-05-17 15:49:31.353|25    |7.55         |
# |14 |14     |12    |2017-05-22 15:33:52.081|15    |7.55         |
# |15 |15     |12    |2017-05-22 01:59:30.835|25    |7.55         |
# |16 |16     |12    |2017-05-23 02:04:44.687|25    |3.12         |
# |17 |17     |12    |2017-05-16 23:12:51.607|15    |7.55         |
# |18 |18     |12    |2017-05-22 16:22:16.5  |15    |7.55         |
# |19 |19     |12    |2017-05-19 10:32:40.832|25    |7.55         |
# +---+-------+------+-----------------------+------+-------------+
# only showing top 20 rows

# %%
loans_sample.count()
# Out:
# 788

# %%
print("Total de valores nulos por coluna:")
for col in loans_sample.columns:
  print(" {}={}".format(col, loans_sample.filter(loans_sample[col].isNull() ).count()) )
# Out:
# Total de valores nulos por coluna:
#  _c0=0
#  loan_id=0
#  period=0
#  accepted_at=0
#  payday=0
#  interest_rate=0

# %%
loans_sample.select("loan_id").distinct().count()
# Out:
# 788

# %% [markdown]
# O dataframe loans_sample apresenta informações como identificador do emprestimo, data aceitação do emprestimo entre outras. Possui 788 registros e não possui valores nulos. Esses registros são referentes a um total de 788 emprestimos realizados.

# %%
installments_sample.show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+
# |            due_date|   installment_value|             loan_id|              number|
# +--------------------+--------------------+--------------------+--------------------+
# |[1497225600000, 1...|[547.92, 547.92, ...|[291, 291, 291, 7...|[1, 2, 8, 6, 9, 1...|
# +--------------------+--------------------+--------------------+--------------------+

# %%
installments_sample.printSchema()
# Out:
# root
#  |-- due_date: struct (nullable = true)
#  |    |-- 0: long (nullable = true)
#  |    |-- 1: long (nullable = true)
#  |    |-- 10: long (nullable = true)
#  |    |-- 100: long (nullable = true)
#  |    |-- 1000: long (nullable = true)
#  |    |-- 1001: long (nullable = true)
#  |    |-- 1002: long (nullable = true)
#  |    |-- 1003: long (nullable = true)
#  |    |-- 1004: long (nullable = true)
#  |    |-- 1005: long (nullable = true)
#  |    |-- 1006: long (nullable = true)
#  |    |-- 1007: long (nullable = true)
#  |    |-- 1008: long (nullable = true)
#  |    |-- 1009: long (nullable = true)
#  |    |-- 101: long (nullable = true)
#  |    |-- 1010: long (nullable = true)
#  |    |-- 1011: long (nullable = true)
#  |    |-- 1012: long (nullable = true)
#  |    |-- 1013: long (nullable = true)
#  |    |-- 1014: long (nullable = true)
#  |    |-- 1015: long (nullable = true)
#  |    |-- 1016: long (nullable = true)
#  |    |-- 1017: long (nullable = true)
#  |    |-- 1018: long (nullable = true)
#  |    |-- 1019: long (nullable = true)
#  |    |-- 102: long (nullable = true)
#  |    |-- 1020: long (nullable = true)
#  |    |-- 1021: long (nullable = true)
#  |    |-- 1022: long (nullable = true)
#  |    |-- 1023: long (nullable = true)
#  |    |-- 1024: long (nullable = true)
#  |    |-- 1025: long (nullable = true)
#  |    |-- 1026: long (nullable = true)
#  |    |-- 1027: long (nullable = true)
#  |    |-- 1028: long (nullable = true)
#  |    |-- 1029: long (nullable = true)
#  |    |-- 103: long (nullable = true)
#  |    |-- 1030: long (nullable = true)
#  |    |-- 1031: long (nullable = true)
#  |    |-- 1032: long (nullable = true)
#  |    |-- 1033: long (nullable = true)
#  |    |-- 1034: long (nullable = true)
#  |    |-- 1035: long (nullable = true)
#  |    |-- 1036: long (nullable = true)
#  |    |-- 1037: long (nullable = true)
#  |    |-- 1038: long (nullable = true)
#  |    |-- 1039: long (nullable = true)
#  |    |-- 104: long (nullable = true)
#  |    |-- 1040: long (nullable = true)
#  |    |-- 1041: long (nullable = true)
#  |    |-- 1042: long (nullable = true)
#  |    |-- 1043: long (nullable = true)
#  |    |-- 1044: long (nullable = true)
#  |    |-- 1045: long (nullable = true)
#  |    |-- 1046: long (nullable = true)
#  |    |-- 1047: long (nullable = true)
#  |    |-- 1048: long (nullable = true)
#  |    |-- 1049: long (nullable = true)
#  |    |-- 105: long (nullable = true)
#  |    |-- 1050: long (nullable = true)
#  |    |-- 1051: long (nullable = true)
#  |    |-- 1052: long (nullable = true)
#  |    |-- 1053: long (nullable = true)
#  |    |-- 1054: long (nullable = true)
#  |    |-- 1055: long (nullable = true)
#  |    |-- 1056: long (nullable = true)
#  |    |-- 1057: long (nullable = true)
#  |    |-- 1058: long (nullable = true)
#  |    |-- 1059: long (nullable = true)
#  |    |-- 106: long (nullable = true)
#  |    |-- 1060: long (nullable = true)
#  |    |-- 1061: long (nullable = true)
#  |    |-- 1062: long (nullable = true)
#  |    |-- 1063: long (nullable = true)
#  |    |-- 1064: long (nullable = true)
#  |    |-- 1065: long (nullable = true)
#  |    |-- 1066: long (nullable = true)
#  |    |-- 1067: long (nullable = true)
#  |    |-- 1068: long (nullable = true)
#  |    |-- 1069: long (nullable = true)
#  |    |-- 107: long (nullable = true)
#  |    |-- 1070: long (nullable = true)
#  |    |-- 1071: long (nullable = true)
#  |    |-- 1072: long (nullable = true)
#  |    |-- 1073: long (nullable = true)
#  |    |-- 1074: long (nullable = true)
#  |    |-- 1075: long (nullable = true)
#  |    |-- 1076: long (nullable = true)
#  |    |-- 1077: long (nullable = true)
#  |    |-- 1078: long (nullable = true)
#  |    |-- 1079: long (nullable = true)
#  |    |-- 108: long (nullable = true)
#  |    |-- 1080: long (nullable = true)
#  |    |-- 1081: long (nullable = true)
#  |    |-- 1082: long (nullable = true)
#  |    |-- 1083: long (nullable = true)
#  |    |-- 1084: long (nullable = true)
#  |    |-- 1085: long (nullable = true)
#  |    |-- 1086: long (nullable = true)
#  |    |-- 1087: long (nullable = true)
#  |    |-- 1088: long (nullable = true)
#  |    |-- 1089: long (nullable = true)
#  |    |-- 109: long (nullable = true)
#  |    |-- 1090: long (nullable = true)
#  |    |-- 1091: long (nullable = true)
#  |    |-- 1092: long (nullable = true)
#  |    |-- 1093: long (nullable = true)
#  |    |-- 1094: long (nullable = true)
#  |    |-- 1095: long (nullable = true)
#  |    |-- 1096: long (nullable = true)
#  |    |-- 1097: long (nullable = true)
#  |    |-- 1098: long (nullable = true)
#  |    |-- 1099: long (nullable = true)
#  |    |-- 11: long (nullable = true)
#  |    |-- 110: long (nullable = true)
#  |    |-- 1100: long (nullable = true)
#  |    |-- 1101: long (nullable = true)
#  |    |-- 1102: long (nullable = true)
#  |    |-- 1103: long (nullable = true)
#  |    |-- 1104: long (nullable = true)
#  |    |-- 1105: long (nullable = true)
#  |    |-- 1106: long (nullable = true)
#  |    |-- 1107: long (nullable = true)
#  |    |-- 1108: long (nullable = true)
#  |    |-- 1109: long (nullable = true)
#  |    |-- 111: long (nullable = true)
#  |    |-- 1110: long (nullable = true)
#  |    |-- 1111: long (nullable = true)
#  |    |-- 1112: long (nullable = true)
#  |    |-- 1113: long (nullable = true)
#  |    |-- 1114: long (nullable = true)
#  |    |-- 1115: long (nullable = true)
#  |    |-- 1116: long (nullable = true)
#  |    |-- 1117: long (nullable = true)
#  |    |-- 1118: long (nullable = true)
#  |    |-- 1119: long (nullable = true)
#  |    |-- 112: long (nullable = true)
#  |    |-- 1120: long (nullable = true)
#  |    |-- 1121: long (nullable = true)
#  |    |-- 1122: long (nullable = true)
#  |    |-- 1123: long (nullable = true)
#  |    |-- 1124: long (nullable = true)
#  |    |-- 1125: long (nullable = true)
#  |    |-- 1126: long (nullable = true)
#  |    |-- 1127: long (nullable = true)
#  |    |-- 1128: long (nullable = true)
#  |    |-- 1129: long (nullable = true)
#  |    |-- 113: long (nullable = true)
#  |    |-- 1130: long (nullable = true)
#  |    |-- 1131: long (nullable = true)
#  |    |-- 1132: long (nullable = true)
#  |    |-- 1133: long (nullable = true)
#  |    |-- 1134: long (nullable = true)
#  |    |-- 1135: long (nullable = true)
#  |    |-- 1136: long (nullable = true)
#  |    |-- 1137: long (nullable = true)
#  |    |-- 1138: long (nullable = true)
#  |    |-- 1139: long (nullable = true)
#  |    |-- 114: long (nullable = true)
#  |    |-- 1140: long (nullable = true)
#  |    |-- 1141: long (nullable = true)
#  |    |-- 1142: long (nullable = true)
#  |    |-- 1143: long (nullable = true)
#  |    |-- 1144: long (nullable = true)
#  |    |-- 1145: long (nullable = true)
#  |    |-- 1146: long (nullable = true)
#  |    |-- 1147: long (nullable = true)
#  |    |-- 1148: long (nullable = true)
#  |    |-- 1149: long (nullable = true)
#  |    |-- 115: long (nullable = true)
#  |    |-- 1150: long (nullable = true)
#  |    |-- 1151: long (nullable = true)
#  |    |-- 1152: long (nullable = true)
#  |    |-- 1153: long (nullable = true)
#  |    |-- 1154: long (nullable = true)
#  |    |-- 1155: long (nullable = true)
#  |    |-- 1156: long (nullable = true)
#  |    |-- 1157: long (nullable = true)
#  |    |-- 1158: long (nullable = true)
#  |    |-- 1159: long (nullable = true)
#  |    |-- 116: long (nullable = true)
#  |    |-- 1160: long (nullable = true)
#  |    |-- 1161: long (nullable = true)
#  |    |-- 1162: long (nullable = true)
#  |    |-- 1163: long (nullable = true)
#  |    |-- 1164: long (nullable = true)
#  |    |-- 1165: long (nullable = true)
#  |    |-- 1166: long (nullable = true)
#  |    |-- 1167: long (nullable = true)
#  |    |-- 1168: long (nullable = true)
#  |    |-- 1169: long (nullable = true)
#  |    |-- 117: long (nullable = true)
#  |    |-- 1170: long (nullable = true)
#  |    |-- 1171: long (nullable = true)
#  |    |-- 1172: long (nullable = true)
#  |    |-- 1173: long (nullable = true)
#  |    |-- 1174: long (nullable = true)
#  |    |-- 1175: long (nullable = true)
#  |    |-- 1176: long (nullable = true)
#  |    |-- 1177: long (nullable = true)
#  |    |-- 1178: long (nullable = true)
#  |    |-- 1179: long (nullable = true)
#  |    |-- 118: long (nullable = true)
#  |    |-- 1180: long (nullable = true)
#  |    |-- 1181: long (nullable = true)
#  |    |-- 1182: long (nullable = true)
#  |    |-- 1183: long (nullable = true)
#  |    |-- 1184: long (nullable = true)
#  |    |-- 1185: long (nullable = true)
#  |    |-- 1186: long (nullable = true)
#  |    |-- 1187: long (nullable = true)
#  |    |-- 1188: long (nullable = true)
#  |    |-- 1189: long (nullable = true)
#  |    |-- 119: long (nullable = true)
#  |    |-- 1190: long (nullable = true)
#  |    |-- 1191: long (nullable = true)
#  |    |-- 1192: long (nullable = true)
#  |    |-- 1193: long (nullable = true)
#  |    |-- 1194: long (nullable = true)
#  |    |-- 1195: long (nullable = true)
#  |    |-- 1196: long (nullable = true)
#  |    |-- 1197: long (nullable = true)
#  |    |-- 1198: long (nullable = true)
#  |    |-- 1199: long (nullable = true)
#  |    |-- 12: long (nullable = true)
#  |    |-- 120: long (nullable = true)
#  |    |-- 1200: long (nullable = true)
#  |    |-- 1201: long (nullable = true)
#  |    |-- 1202: long (nullable = true)
#  |    |-- 1203: long (nullable = true)
#  |    |-- 1204: long (nullable = true)
#  |    |-- 1205: long (nullable = true)
#  |    |-- 1206: long (nullable = true)
#  |    |-- 1207: long (nullable = true)
#  |    |-- 1208: long (nullable = true)
#  |    |-- 1209: long (nullable = true)
#  |    |-- 121: long (nullable = true)
#  |    |-- 1210: long (nullable = true)
#  |    |-- 1211: long (nullable = true)
#  |    |-- 1212: long (nullable = true)
#  |    |-- 1213: long (nullable = true)
#  |    |-- 1214: long (nullable = true)
#  |    |-- 1215: long (nullable = true)
#  |    |-- 1216: long (nullable = true)
#  |    |-- 1217: long (nullable = true)
#  |    |-- 1218: long (nullable = true)
#  |    |-- 1219: long (nullable = true)
#  |    |-- 122: long (nullable = true)
#  |    |-- 1220: long (nullable = true)
#  |    |-- 1221: long (nullable = true)
#  |    |-- 1222: long (nullable = true)
#  |    |-- 1223: long (nullable = true)
#  |    |-- 1224: long (nullable = true)
#  |    |-- 1225: long (nullable = true)
#  |    |-- 1226: long (nullable = true)
#  |    |-- 1227: long (nullable = true)
#  |    |-- 1228: long (nullable = true)
#  |    |-- 1229: long (nullable = true)
#  |    |-- 123: long (nullable = true)
#  |    |-- 1230: long (nullable = true)
#  |    |-- 1231: long (nullable = true)
#  |    |-- 1232: long (nullable = true)
#  |    |-- 1233: long (nullable = true)
#  |    |-- 1234: long (nullable = true)
#  |    |-- 1235: long (nullable = true)
#  |    |-- 1236: long (nullable = true)
#  |    |-- 1237: long (nullable = true)
#  |    |-- 1238: long (nullable = true)
#  |    |-- 1239: long (nullable = true)
#  |    |-- 124: long (nullable = true)
#  |    |-- 1240: long (nullable = true)
#  |    |-- 1241: long (nullable = true)
#  |    |-- 1242: long (nullable = true)
#  |    |-- 1243: long (nullable = true)
#  |    |-- 1244: long (nullable = true)
#  |    |-- 1245: long (nullable = true)
#  |    |-- 1246: long (nullable = true)
#  |    |-- 1247: long (nullable = true)
#  |    |-- 1248: long (nullable = true)
#  |    |-- 1249: long (nullable = true)
#  |    |-- 125: long (nullable = true)
#  |    |-- 1250: long (nullable = true)
#  |    |-- 1251: long (nullable = true)
#  |    |-- 1252: long (nullable = true)
#  |    |-- 1253: long (nullable = true)
#  |    |-- 1254: long (nullable = true)
#  |    |-- 1255: long (nullable = true)
#  |    |-- 1256: long (nullable = true)
#  |    |-- 1257: long (nullable = true)
#  |    |-- 1258: long (nullable = true)
#  |    |-- 1259: long (nullable = true)
#  |    |-- 126: long (nullable = true)
#  |    |-- 1260: long (nullable = true)
#  |    |-- 1261: long (nullable = true)
#  |    |-- 1262: long (nullable = true)
#  |    |-- 1263: long (nullable = true)
#  |    |-- 1264: long (nullable = true)
#  |    |-- 1265: long (nullable = true)
#  |    |-- 1266: long (nullable = true)
#  |    |-- 1267: long (nullable = true)
#  |    |-- 1268: long (nullable = true)
#  |    |-- 1269: long (nullable = true)
#  |    |-- 127: long (nullable = true)
#  |    |-- 1270: long (nullable = true)
#  |    |-- 1271: long (nullable = true)
#  |    |-- 1272: long (nullable = true)
#  |    |-- 1273: long (nullable = true)
#  |    |-- 1274: long (nullable = true)
#  |    |-- 1275: long (nullable = true)
#  |    |-- 1276: long (nullable = true)
#  |    |-- 1277: long (nullable = true)
#  |    |-- 1278: long (nullable = true)
#  |    |-- 1279: long (nullable = true)
#  |    |-- 128: long (nullable = true)
#  |    |-- 1280: long (nullable = true)
#  |    |-- 1281: long (nullable = true)
#  |    |-- 1282: long (nullable = true)
#  |    |-- 1283: long (nullable = true)
#  |    |-- 1284: long (nullable = true)
#  |    |-- 1285: long (nullable = true)
#  |    |-- 1286: long (nullable = true)
#  |    |-- 1287: long (nullable = true)
#  |    |-- 1288: long (nullable = true)
#  |    |-- 1289: long (nullable = true)
#  |    |-- 129: long (nullable = true)
#  |    |-- 1290: long (nullable = true)
#  |    |-- 1291: long (nullable = true)
#  |    |-- 1292: long (nullable = true)
#  |    |-- 1293: long (nullable = true)
#  |    |-- 1294: long (nullable = true)
#  |    |-- 1295: long (nullable = true)
#  |    |-- 1296: long (nullable = true)
#  |    |-- 1297: long (nullable = true)
#  |    |-- 1298: long (nullable = true)
#  |    |-- 1299: long (nullable = true)
#  |    |-- 13: long (nullable = true)
#  |    |-- 130: long (nullable = true)
#  |    |-- 1300: long (nullable = true)
#  |    |-- 1301: long (nullable = true)
#  |    |-- 1302: long (nullable = true)
#  |    |-- 1303: long (nullable = true)
#  |    |-- 1304: long (nullable = true)
#  |    |-- 1305: long (nullable = true)
#  |    |-- 1306: long (nullable = true)
#  |    |-- 1307: long (nullable = true)
#  |    |-- 1308: long (nullable = true)
#  |    |-- 1309: long (nullable = true)
#  |    |-- 131: long (nullable = true)
#  |    |-- 1310: long (nullable = true)
#  |    |-- 1311: long (nullable = true)
#  |    |-- 1312: long (nullable = true)
#  |    |-- 1313: long (nullable = true)
#  |    |-- 1314: long (nullable = true)
#  |    |-- 1315: long (nullable = true)
#  |    |-- 1316: long (nullable = true)
#  |    |-- 1317: long (nullable = true)
#  |    |-- 1318: long (nullable = true)
#  |    |-- 1319: long (nullable = true)
#  |    |-- 132: long (nullable = true)
#  |    |-- 1320: long (nullable = true)
#  |    |-- 1321: long (nullable = true)
#  |    |-- 1322: long (nullable = true)
#  |    |-- 1323: long (nullable = true)
#  |    |-- 1324: long (nullable = true)
#  |    |-- 1325: long (nullable = true)
#  |    |-- 1326: long (nullable = true)
#  |    |-- 1327: long (nullable = true)
#  |    |-- 1328: long (nullable = true)
#  |    |-- 1329: long (nullable = true)
#  |    |-- 133: long (nullable = true)
#  |    |-- 1330: long (nullable = true)
#  |    |-- 1331: long (nullable = true)
#  |    |-- 1332: long (nullable = true)
#  |    |-- 1333: long (nullable = true)
#  |    |-- 1334: long (nullable = true)
#  |    |-- 1335: long (nullable = true)
#  |    |-- 1336: long (nullable = true)
#  |    |-- 1337: long (nullable = true)
#  |    |-- 1338: long (nullable = true)
#  |    |-- 1339: long (nullable = true)
#  |    |-- 134: long (nullable = true)
#  |    |-- 1340: long (nullable = true)
#  |    |-- 1341: long (nullable = true)
#  |    |-- 1342: long (nullable = true)
#  |    |-- 1343: long (nullable = true)
#  |    |-- 1344: long (nullable = true)
#  |    |-- 1345: long (nullable = true)
#  |    |-- 1346: long (nullable = true)
#  |    |-- 1347: long (nullable = true)
#  |    |-- 1348: long (nullable = true)
#  |    |-- 1349: long (nullable = true)
#  |    |-- 135: long (nullable = true)
#  |    |-- 1350: long (nullable = true)
#  |    |-- 1351: long (nullable = true)
#  |    |-- 1352: long (nullable = true)
#  |    |-- 1353: long (nullable = true)
#  |    |-- 1354: long (nullable = true)
#  |    |-- 1355: long (nullable = true)
#  |    |-- 1356: long (nullable = true)
#  |    |-- 1357: long (nullable = true)
#  |    |-- 1358: long (nullable = true)
#  |    |-- 1359: long (nullable = true)
#  |    |-- 136: long (nullable = true)
#  |    |-- 1360: long (nullable = true)
#  |    |-- 1361: long (nullable = true)
#  |    |-- 1362: long (nullable = true)
#  |    |-- 1363: long (nullable = true)
#  |    |-- 1364: long (nullable = true)
#  |    |-- 1365: long (nullable = true)
#  |    |-- 1366: long (nullable = true)
#  |    |-- 1367: long (nullable = true)
#  |    |-- 1368: long (nullable = true)
#  |    |-- 1369: long (nullable = true)
#  |    |-- 137: long (nullable = true)
#  |    |-- 1370: long (nullable = true)
#  |    |-- 1371: long (nullable = true)
#  |    |-- 1372: long (nullable = true)
#  |    |-- 1373: long (nullable = true)
#  |    |-- 1374: long (nullable = true)
#  |    |-- 1375: long (nullable = true)
#  |    |-- 1376: long (nullable = true)
#  |    |-- 1377: long (nullable = true)
#  |    |-- 1378: long (nullable = true)
#  |    |-- 1379: long (nullable = true)
#  |    |-- 138: long (nullable = true)
#  |    |-- 1380: long (nullable = true)
#  |    |-- 1381: long (nullable = true)
#  |    |-- 1382: long (nullable = true)
#  |    |-- 1383: long (nullable = true)
#  |    |-- 1384: long (nullable = true)
#  |    |-- 1385: long (nullable = true)
#  |    |-- 1386: long (nullable = true)
#  |    |-- 1387: long (nullable = true)
#  |    |-- 1388: long (nullable = true)
#  |    |-- 1389: long (nullable = true)
#  |    |-- 139: long (nullable = true)
#  |    |-- 1390: long (nullable = true)
#  |    |-- 1391: long (nullable = true)
#  |    |-- 1392: long (nullable = true)
#  |    |-- 1393: long (nullable = true)
#  |    |-- 1394: long (nullable = true)
#  |    |-- 1395: long (nullable = true)
#  |    |-- 1396: long (nullable = true)
#  |    |-- 1397: long (nullable = true)
#  |    |-- 1398: long (nullable = true)
#  |    |-- 1399: long (nullable = true)
#  |    |-- 14: long (nullable = true)
#  |    |-- 140: long (nullable = true)
#  |    |-- 1400: long (nullable = true)
#  |    |-- 1401: long (nullable = true)
#  |    |-- 1402: long (nullable = true)
#  |    |-- 1403: long (nullable = true)
#  |    |-- 1404: long (nullable = true)
#  |    |-- 1405: long (nullable = true)
#  |    |-- 1406: long (nullable = true)
#  |    |-- 1407: long (nullable = true)
#  |    |-- 1408: long (nullable = true)
#  |    |-- 1409: long (nullable = true)
#  |    |-- 141: long (nullable = true)
#  |    |-- 1410: long (nullable = true)
#  |    |-- 1411: long (nullable = true)
#  |    |-- 1412: long (nullable = true)
#  |    |-- 1413: long (nullable = true)
#  |    |-- 1414: long (nullable = true)
#  |    |-- 1415: long (nullable = true)
#  |    |-- 1416: long (nullable = true)
#  |    |-- 1417: long (nullable = true)
#  |    |-- 1418: long (nullable = true)
#  |    |-- 1419: long (nullable = true)
#  |    |-- 142: long (nullable = true)
#  |    |-- 1420: long (nullable = true)
#  |    |-- 1421: long (nullable = true)
#  |    |-- 1422: long (nullable = true)
#  |    |-- 1423: long (nullable = true)
#  |    |-- 1424: long (nullable = true)
#  |    |-- 1425: long (nullable = true)
#  |    |-- 1426: long (nullable = true)
#  |    |-- 1427: long (nullable = true)
#  |    |-- 1428: long (nullable = true)
#  |    |-- 1429: long (nullable = true)
#  |    |-- 143: long (nullable = true)
#  |    |-- 1430: long (nullable = true)
#  |    |-- 1431: long (nullable = true)
#  |    |-- 1432: long (nullable = true)
#  |    |-- 1433: long (nullable = true)
#  |    |-- 1434: long (nullable = true)
#  |    |-- 1435: long (nullable = true)
#  |    |-- 1436: long (nullable = true)
#  |    |-- 1437: long (nullable = true)
#  |    |-- 1438: long (nullable = true)
#  |    |-- 1439: long (nullable = true)
#  |    |-- 144: long (nullable = true)
#  |    |-- 1440: long (nullable = true)
#  |    |-- 1441: long (nullable = true)
#  |    |-- 1442: long (nullable = true)
#  |    |-- 1443: long (nullable = true)
#  |    |-- 1444: long (nullable = true)
#  |    |-- 1445: long (nullable = true)
#  |    |-- 1446: long (nullable = true)
#  |    |-- 1447: long (nullable = true)
#  |    |-- 1448: long (nullable = true)
#  |    |-- 1449: long (nullable = true)
#  |    |-- 145: long (nullable = true)
#  |    |-- 1450: long (nullable = true)
#  |    |-- 1451: long (nullable = true)
#  |    |-- 1452: long (nullable = true)
#  |    |-- 1453: long (nullable = true)
#  |    |-- 1454: long (nullable = true)
#  |    |-- 1455: long (nullable = true)
#  |    |-- 1456: long (nullable = true)
#  |    |-- 1457: long (nullable = true)
#  |    |-- 1458: long (nullable = true)
#  |    |-- 1459: long (nullable = true)
#  |    |-- 146: long (nullable = true)
#  |    |-- 1460: long (nullable = true)
#  |    |-- 1461: long (nullable = true)
#  |    |-- 1462: long (nullable = true)
#  |    |-- 1463: long (nullable = true)
#  |    |-- 1464: long (nullable = true)
#  |    |-- 1465: long (nullable = true)
#  |    |-- 1466: long (nullable = true)
#  |    |-- 1467: long (nullable = true)
#  |    |-- 1468: long (nullable = true)
#  |    |-- 1469: long (nullable = true)
#  |    |-- 147: long (nullable = true)
#  |    |-- 1470: long (nullable = true)
#  |    |-- 1471: long (nullable = true)
#  |    |-- 1472: long (nullable = true)
#  |    |-- 1473: long (nullable = true)
#  |    |-- 1474: long (nullable = true)
#  |    |-- 1475: long (nullable = true)
#  |    |-- 1476: long (nullable = true)
#  |    |-- 1477: long (nullable = true)
#  |    |-- 1478: long (nullable = true)
#  |    |-- 1479: long (nullable = true)
#  |    |-- 148: long (nullable = true)
#  |    |-- 1480: long (nullable = true)
#  |    |-- 1481: long (nullable = true)
#  |    |-- 1482: long (nullable = true)
#  |    |-- 1483: long (nullable = true)
#  |    |-- 1484: long (nullable = true)
#  |    |-- 1485: long (nullable = true)
#  |    |-- 1486: long (nullable = true)
#  |    |-- 1487: long (nullable = true)
#  |    |-- 1488: long (nullable = true)
#  |    |-- 1489: long (nullable = true)
#  |    |-- 149: long (nullable = true)
#  |    |-- 1490: long (nullable = true)
#  |    |-- 1491: long (nullable = true)
#  |    |-- 1492: long (nullable = true)
#  |    |-- 1493: long (nullable = true)
#  |    |-- 1494: long (nullable = true)
#  |    |-- 1495: long (nullable = true)
#  |    |-- 1496: long (nullable = true)
#  |    |-- 1497: long (nullable = true)
#  |    |-- 1498: long (nullable = true)
#  |    |-- 1499: long (nullable = true)
#  |    |-- 15: long (nullable = true)
#  |    |-- 150: long (nullable = true)
#  |    |-- 1500: long (nullable = true)
#  |    |-- 1501: long (nullable = true)
#  |    |-- 1502: long (nullable = true)
#  |    |-- 1503: long (nullable = true)
#  |    |-- 1504: long (nullable = true)
#  |    |-- 1505: long (nullable = true)
#  |    |-- 1506: long (nullable = true)
#  |    |-- 1507: long (nullable = true)
#  |    |-- 1508: long (nullable = true)
#  |    |-- 1509: long (nullable = true)
#  |    |-- 151: long (nullable = true)
#  |    |-- 1510: long (nullable = true)
#  |    |-- 1511: long (nullable = true)
#  |    |-- 1512: long (nullable = true)
#  |    |-- 1513: long (nullable = true)
#  |    |-- 1514: long (nullable = true)
#  |    |-- 1515: long (nullable = true)
#  |    |-- 1516: long (nullable = true)
#  |    |-- 1517: long (nullable = true)
#  |    |-- 1518: long (nullable = true)
#  |    |-- 1519: long (nullable = true)
#  |    |-- 152: long (nullable = true)
#  |    |-- 1520: long (nullable = true)
#  |    |-- 1521: long (nullable = true)
#  |    |-- 1522: long (nullable = true)
#  |    |-- 1523: long (nullable = true)
#  |    |-- 1524: long (nullable = true)
#  |    |-- 1525: long (nullable = true)
#  |    |-- 1526: long (nullable = true)
#  |    |-- 1527: long (nullable = true)
#  |    |-- 1528: long (nullable = true)
#  |    |-- 1529: long (nullable = true)
#  |    |-- 153: long (nullable = true)
#  |    |-- 1530: long (nullable = true)
#  |    |-- 1531: long (nullable = true)
#  |    |-- 1532: long (nullable = true)
#  |    |-- 1533: long (nullable = true)
#  |    |-- 1534: long (nullable = true)
#  |    |-- 1535: long (nullable = true)
#  |    |-- 1536: long (nullable = true)
#  |    |-- 1537: long (nullable = true)
#  |    |-- 1538: long (nullable = true)
#  |    |-- 1539: long (nullable = true)
#  |    |-- 154: long (nullable = true)
#  |    |-- 1540: long (nullable = true)
#  |    |-- 1541: long (nullable = true)
#  |    |-- 1542: long (nullable = true)
#  |    |-- 1543: long (nullable = true)
#  |    |-- 1544: long (nullable = true)
#  |    |-- 1545: long (nullable = true)
#  |    |-- 1546: long (nullable = true)
#  |    |-- 1547: long (nullable = true)
#  |    |-- 1548: long (nullable = true)
#  |    |-- 1549: long (nullable = true)
#  |    |-- 155: long (nullable = true)
#  |    |-- 1550: long (nullable = true)
#  |    |-- 1551: long (nullable = true)
#  |    |-- 1552: long (nullable = true)
#  |    |-- 1553: long (nullable = true)
#  |    |-- 1554: long (nullable = true)
#  |    |-- 1555: long (nullable = true)
#  |    |-- 1556: long (nullable = true)
#  |    |-- 1557: long (nullable = true)
#  |    |-- 1558: long (nullable = true)
#  |    |-- 1559: long (nullable = true)
#  |    |-- 156: long (nullable = true)
#  |    |-- 1560: long (nullable = true)
#  |    |-- 1561: long (nullable = true)
#  |    |-- 1562: long (nullable = true)
#  |    |-- 1563: long (nullable = true)
#  |    |-- 1564: long (nullable = true)
#  |    |-- 1565: long (nullable = true)
#  |    |-- 1566: long (nullable = true)
#  |    |-- 1567: long (nullable = true)
#  |    |-- 1568: long (nullable = true)
#  |    |-- 1569: long (nullable = true)
#  |    |-- 157: long (nullable = true)
#  |    |-- 1570: long (nullable = true)
#  |    |-- 1571: long (nullable = true)
#  |    |-- 1572: long (nullable = true)
#  |    |-- 1573: long (nullable = true)
#  |    |-- 1574: long (nullable = true)
#  |    |-- 1575: long (nullable = true)
#  |    |-- 1576: long (nullable = true)
#  |    |-- 1577: long (nullable = true)
#  |    |-- 1578: long (nullable = true)
#  |    |-- 1579: long (nullable = true)
#  |    |-- 158: long (nullable = true)
#  |    |-- 1580: long (nullable = true)
#  |    |-- 1581: long (nullable = true)
#  |    |-- 1582: long (nullable = true)
#  |    |-- 1583: long (nullable = true)
#  |    |-- 1584: long (nullable = true)
#  |    |-- 1585: long (nullable = true)
#  |    |-- 1586: long (nullable = true)
#  |    |-- 1587: long (nullable = true)
#  |    |-- 1588: long (nullable = true)
#  |    |-- 1589: long (nullable = true)
#  |    |-- 159: long (nullable = true)
#  |    |-- 1590: long (nullable = true)
#  |    |-- 1591: long (nullable = true)
#  |    |-- 1592: long (nullable = true)
#  |    |-- 1593: long (nullable = true)
#  |    |-- 1594: long (nullable = true)
#  |    |-- 1595: long (nullable = true)
#  |    |-- 1596: long (nullable = true)
#  |    |-- 1597: long (nullable = true)
#  |    |-- 1598: long (nullable = true)
#  |    |-- 1599: long (nullable = true)
#  |    |-- 16: long (nullable = true)
#  |    |-- 160: long (nullable = true)
#  |    |-- 1600: long (nullable = true)
#  |    |-- 1601: long (nullable = true)
#  |    |-- 1602: long (nullable = true)
#  |    |-- 1603: long (nullable = true)
#  |    |-- 1604: long (nullable = true)
#  |    |-- 1605: long (nullable = true)
#  |    |-- 1606: long (nullable = true)
#  |    |-- 1607: long (nullable = true)
#  |    |-- 1608: long (nullable = true)
#  |    |-- 1609: long (nullable = true)
#  |    |-- 161: long (nullable = true)
#  |    |-- 1610: long (nullable = true)
#  |    |-- 1611: long (nullable = true)
#  |    |-- 1612: long (nullable = true)
#  |    |-- 1613: long (nullable = true)
#  |    |-- 1614: long (nullable = true)
#  |    |-- 1615: long (nullable = true)
#  |    |-- 1616: long (nullable = true)
#  |    |-- 1617: long (nullable = true)
#  |    |-- 1618: long (nullable = true)
#  |    |-- 1619: long (nullable = true)
#  |    |-- 162: long (nullable = true)
#  |    |-- 1620: long (nullable = true)
#  |    |-- 1621: long (nullable = true)
#  |    |-- 1622: long (nullable = true)
#  |    |-- 1623: long (nullable = true)
#  |    |-- 1624: long (nullable = true)
#  |    |-- 1625: long (nullable = true)
#  |    |-- 1626: long (nullable = true)
#  |    |-- 1627: long (nullable = true)
#  |    |-- 1628: long (nullable = true)
#  |    |-- 1629: long (nullable = true)
#  |    |-- 163: long (nullable = true)
#  |    |-- 1630: long (nullable = true)
#  |    |-- 1631: long (nullable = true)
#  |    |-- 1632: long (nullable = true)
#  |    |-- 1633: long (nullable = true)
#  |    |-- 1634: long (nullable = true)
#  |    |-- 1635: long (nullable = true)
#  |    |-- 1636: long (nullable = true)
#  |    |-- 1637: long (nullable = true)
#  |    |-- 1638: long (nullable = true)
#  |    |-- 1639: long (nullable = true)
#  |    |-- 164: long (nullable = true)
#  |    |-- 1640: long (nullable = true)
#  |    |-- 1641: long (nullable = true)
#  |    |-- 1642: long (nullable = true)
#  |    |-- 1643: long (nullable = true)
#  |    |-- 1644: long (nullable = true)
#  |    |-- 1645: long (nullable = true)
#  |    |-- 1646: long (nullable = true)
#  |    |-- 1647: long (nullable = true)
#  |    |-- 1648: long (nullable = true)
#  |    |-- 1649: long (nullable = true)
#  |    |-- 165: long (nullable = true)
#  |    |-- 1650: long (nullable = true)
#  |    |-- 1651: long (nullable = true)
#  |    |-- 1652: long (nullable = true)
#  |    |-- 1653: long (nullable = true)
#  |    |-- 1654: long (nullable = true)
#  |    |-- 1655: long (nullable = true)
#  |    |-- 1656: long (nullable = true)
#  |    |-- 1657: long (nullable = true)
#  |    |-- 1658: long (nullable = true)
#  |    |-- 1659: long (nullable = true)
#  |    |-- 166: long (nullable = true)
#  |    |-- 1660: long (nullable = true)
#  |    |-- 1661: long (nullable = true)
#  |    |-- 1662: long (nullable = true)
#  |    |-- 1663: long (nullable = true)
#  |    |-- 1664: long (nullable = true)
#  |    |-- 1665: long (nullable = true)
#  |    |-- 1666: long (nullable = true)
#  |    |-- 1667: long (nullable = true)
#  |    |-- 1668: long (nullable = true)
#  |    |-- 1669: long (nullable = true)
#  |    |-- 167: long (nullable = true)
#  |    |-- 1670: long (nullable = true)
#  |    |-- 1671: long (nullable = true)
#  |    |-- 1672: long (nullable = true)
#  |    |-- 1673: long (nullable = true)
#  |    |-- 1674: long (nullable = true)
#  |    |-- 1675: long (nullable = true)
#  |    |-- 1676: long (nullable = true)
#  |    |-- 1677: long (nullable = true)
#  |    |-- 1678: long (nullable = true)
#  |    |-- 1679: long (nullable = true)
#  |    |-- 168: long (nullable = true)
#  |    |-- 1680: long (nullable = true)
#  |    |-- 1681: long (nullable = true)
#  |    |-- 1682: long (nullable = true)
#  |    |-- 1683: long (nullable = true)
#  |    |-- 1684: long (nullable = true)
#  |    |-- 1685: long (nullable = true)
#  |    |-- 1686: long (nullable = true)
#  |    |-- 1687: long (nullable = true)
#  |    |-- 1688: long (nullable = true)
#  |    |-- 1689: long (nullable = true)
#  |    |-- 169: long (nullable = true)
#  |    |-- 1690: long (nullable = true)
#  |    |-- 1691: long (nullable = true)
#  |    |-- 1692: long (nullable = true)
#  |    |-- 1693: long (nullable = true)
#  |    |-- 1694: long (nullable = true)
#  |    |-- 1695: long (nullable = true)
#  |    |-- 1696: long (nullable = true)
#  |    |-- 1697: long (nullable = true)
#  |    |-- 1698: long (nullable = true)
#  |    |-- 1699: long (nullable = true)
#  |    |-- 17: long (nullable = true)
#  |    |-- 170: long (nullable = true)
#  |    |-- 1700: long (nullable = true)
#  |    |-- 1701: long (nullable = true)
#  |    |-- 1702: long (nullable = true)
#  |    |-- 1703: long (nullable = true)
#  |    |-- 1704: long (nullable = true)
#  |    |-- 1705: long (nullable = true)
#  |    |-- 1706: long (nullable = true)
#  |    |-- 1707: long (nullable = true)
#  |    |-- 1708: long (nullable = true)
#  |    |-- 1709: long (nullable = true)
#  |    |-- 171: long (nullable = true)
#  |    |-- 1710: long (nullable = true)
#  |    |-- 1711: long (nullable = true)
#  |    |-- 1712: long (nullable = true)
#  |    |-- 1713: long (nullable = true)
#  |    |-- 1714: long (nullable = true)
#  |    |-- 1715: long (nullable = true)
#  |    |-- 1716: long (nullable = true)
#  |    |-- 1717: long (nullable = true)
#  |    |-- 1718: long (nullable = true)
#  |    |-- 1719: long (nullable = true)
#  |    |-- 172: long (nullable = true)
#  |    |-- 1720: long (nullable = true)
#  |    |-- 1721: long (nullable = true)
#  |    |-- 1722: long (nullable = true)
#  |    |-- 1723: long (nullable = true)
#  |    |-- 1724: long (nullable = true)
#  |    |-- 1725: long (nullable = true)
#  |    |-- 1726: long (nullable = true)
#  |    |-- 1727: long (nullable = true)
#  |    |-- 1728: long (nullable = true)
#  |    |-- 1729: long (nullable = true)
#  |    |-- 173: long (nullable = true)
#  |    |-- 1730: long (nullable = true)
#  |    |-- 1731: long (nullable = true)
#  |    |-- 1732: long (nullable = true)
#  |    |-- 1733: long (nullable = true)
#  |    |-- 1734: long (nullable = true)
#  |    |-- 1735: long (nullable = true)
#  |    |-- 1736: long (nullable = true)
#  |    |-- 1737: long (nullable = true)
#  |    |-- 1738: long (nullable = true)
#  |    |-- 1739: long (nullable = true)
#  |    |-- 174: long (nullable = true)
#  |    |-- 1740: long (nullable = true)
#  |    |-- 1741: long (nullable = true)
#  |    |-- 1742: long (nullable = true)
#  |    |-- 1743: long (nullable = true)
#  |    |-- 1744: long (nullable = true)
#  |    |-- 1745: long (nullable = true)
#  |    |-- 1746: long (nullable = true)
#  |    |-- 1747: long (nullable = true)
#  |    |-- 1748: long (nullable = true)
#  |    |-- 1749: long (nullable = true)
#  |    |-- 175: long (nullable = true)
#  |    |-- 1750: long (nullable = true)
#  |    |-- 1751: long (nullable = true)
#  |    |-- 1752: long (nullable = true)
#  |    |-- 1753: long (nullable = true)
#  |    |-- 1754: long (nullable = true)
#  |    |-- 1755: long (nullable = true)
#  |    |-- 1756: long (nullable = true)
#  |    |-- 1757: long (nullable = true)
#  |    |-- 1758: long (nullable = true)
#  |    |-- 1759: long (nullable = true)
#  |    |-- 176: long (nullable = true)
#  |    |-- 1760: long (nullable = true)
#  |    |-- 1761: long (nullable = true)
#  |    |-- 1762: long (nullable = true)
#  |    |-- 1763: long (nullable = true)
#  |    |-- 1764: long (nullable = true)
#  |    |-- 1765: long (nullable = true)
#  |    |-- 1766: long (nullable = true)
#  |    |-- 1767: long (nullable = true)
#  |    |-- 1768: long (nullable = true)
#  |    |-- 1769: long (nullable = true)
#  |    |-- 177: long (nullable = true)
#  |    |-- 1770: long (nullable = true)
#  |    |-- 1771: long (nullable = true)
#  |    |-- 1772: long (nullable = true)
#  |    |-- 1773: long (nullable = true)
#  |    |-- 1774: long (nullable = true)
#  |    |-- 1775: long (nullable = true)
#  |    |-- 1776: long (nullable = true)
#  |    |-- 1777: long (nullable = true)
#  |    |-- 1778: long (nullable = true)
#  |    |-- 1779: long (nullable = true)
#  |    |-- 178: long (nullable = true)
#  |    |-- 1780: long (nullable = true)
#  |    |-- 1781: long (nullable = true)
#  |    |-- 1782: long (nullable = true)
#  |    |-- 1783: long (nullable = true)
#  |    |-- 1784: long (nullable = true)
#  |    |-- 1785: long (nullable = true)
#  |    |-- 1786: long (nullable = true)
#  |    |-- 1787: long (nullable = true)
#  |    |-- 1788: long (nullable = true)
#  |    |-- 1789: long (nullable = true)
#  |    |-- 179: long (nullable = true)
#  |    |-- 1790: long (nullable = true)
#  |    |-- 1791: long (nullable = true)
#  |    |-- 1792: long (nullable = true)
#  |    |-- 1793: long (nullable = true)
#  |    |-- 1794: long (nullable = true)
#  |    |-- 1795: long (nullable = true)
#  |    |-- 1796: long (nullable = true)
#  |    |-- 1797: long (nullable = true)
#  |    |-- 1798: long (nullable = true)
#  |    |-- 1799: long (nullable = true)
#  |    |-- 18: long (nullable = true)
#  |    |-- 180: long (nullable = true)
#  |    |-- 1800: long (nullable = true)
#  |    |-- 1801: long (nullable = true)
#  |    |-- 1802: long (nullable = true)
#  |    |-- 1803: long (nullable = true)
#  |    |-- 1804: long (nullable = true)
#  |    |-- 1805: long (nullable = true)
#  |    |-- 1806: long (nullable = true)
#  |    |-- 1807: long (nullable = true)
#  |    |-- 1808: long (nullable = true)
#  |    |-- 1809: long (nullable = true)
#  |    |-- 181: long (nullable = true)
#  |    |-- 1810: long (nullable = true)
#  |    |-- 1811: long (nullable = true)
#  |    |-- 1812: long (nullable = true)
#  |    |-- 1813: long (nullable = true)
#  |    |-- 1814: long (nullable = true)
#  |    |-- 1815: long (nullable = true)
#  |    |-- 1816: long (nullable = true)
#  |    |-- 1817: long (nullable = true)
#  |    |-- 1818: long (nullable = true)
#  |    |-- 1819: long (nullable = true)
#  |    |-- 182: long (nullable = true)
#  |    |-- 1820: long (nullable = true)
#  |    |-- 1821: long (nullable = true)
#  |    |-- 1822: long (nullable = true)
#  |    |-- 1823: long (nullable = true)
#  |    |-- 1824: long (nullable = true)
#  |    |-- 1825: long (nullable = true)
#  |    |-- 1826: long (nullable = true)
#  |    |-- 1827: long (nullable = true)
#  |    |-- 1828: long (nullable = true)
#  |    |-- 1829: long (nullable = true)
#  |    |-- 183: long (nullable = true)
#  |    |-- 1830: long (nullable = true)
#  |    |-- 1831: long (nullable = true)
#  |    |-- 1832: long (nullable = true)
#  |    |-- 1833: long (nullable = true)
#  |    |-- 1834: long (nullable = true)
#  |    |-- 1835: long (nullable = true)
#  |    |-- 1836: long (nullable = true)
#  |    |-- 1837: long (nullable = true)
#  |    |-- 1838: long (nullable = true)
#  |    |-- 1839: long (nullable = true)
#  |    |-- 184: long (nullable = true)
#  |    |-- 1840: long (nullable = true)
#  |    |-- 1841: long (nullable = true)
#  |    |-- 1842: long (nullable = true)
#  |    |-- 1843: long (nullable = true)
#  |    |-- 1844: long (nullable = true)
#  |    |-- 1845: long (nullable = true)
#  |    |-- 1846: long (nullable = true)
#  |    |-- 1847: long (nullable = true)
#  |    |-- 1848: long (nullable = true)
#  |    |-- 1849: long (nullable = true)
#  |    |-- 185: long (nullable = true)
#  |    |-- 1850: long (nullable = true)
#  |    |-- 1851: long (nullable = true)
#  |    |-- 1852: long (nullable = true)
#  |    |-- 1853: long (nullable = true)
#  |    |-- 1854: long (nullable = true)
#  |    |-- 1855: long (nullable = true)
#  |    |-- 1856: long (nullable = true)
#  |    |-- 1857: long (nullable = true)
#  |    |-- 1858: long (nullable = true)
#  |    |-- 1859: long (nullable = true)
#  |    |-- 186: long (nullable = true)
#  |    |-- 1860: long (nullable = true)
#  |    |-- 1861: long (nullable = true)
#  |    |-- 1862: long (nullable = true)
#  |    |-- 1863: long (nullable = true)
#  |    |-- 1864: long (nullable = true)
#  |    |-- 1865: long (nullable = true)
#  |    |-- 1866: long (nullable = true)
#  |    |-- 1867: long (nullable = true)
#  |    |-- 1868: long (nullable = true)
#  |    |-- 1869: long (nullable = true)
#  |    |-- 187: long (nullable = true)
#  |    |-- 1870: long (nullable = true)
#  |    |-- 1871: long (nullable = true)
#  |    |-- 1872: long (nullable = true)
#  |    |-- 1873: long (nullable = true)
#  |    |-- 1874: long (nullable = true)
#  |    |-- 1875: long (nullable = true)
#  |    |-- 1876: long (nullable = true)
#  |    |-- 1877: long (nullable = true)
#  |    |-- 1878: long (nullable = true)
#  |    |-- 1879: long (nullable = true)
#  |    |-- 188: long (nullable = true)
#  |    |-- 1880: long (nullable = true)
#  |    |-- 1881: long (nullable = true)
#  |    |-- 1882: long (nullable = true)
#  |    |-- 1883: long (nullable = true)
#  |    |-- 1884: long (nullable = true)
#  |    |-- 1885: long (nullable = true)
#  |    |-- 1886: long (nullable = true)
#  |    |-- 1887: long (nullable = true)
#  |    |-- 1888: long (nullable = true)
#  |    |-- 1889: long (nullable = true)
#  |    |-- 189: long (nullable = true)
#  |    |-- 1890: long (nullable = true)
#  |    |-- 1891: long (nullable = true)
#  |    |-- 1892: long (nullable = true)
#  |    |-- 1893: long (nullable = true)
#  |    |-- 1894: long (nullable = true)
#  |    |-- 1895: long (nullable = true)
#  |    |-- 1896: long (nullable = true)
#  |    |-- 1897: long (nullable = true)
#  |    |-- 1898: long (nullable = true)
#  |    |-- 1899: long (nullable = true)
#  |    |-- 19: long (nullable = true)
#  |    |-- 190: long (nullable = true)
#  |    |-- 1900: long (nullable = true)
#  |    |-- 1901: long (nullable = true)
#  |    |-- 1902: long (nullable = true)
#  |    |-- 1903: long (nullable = true)
#  |    |-- 1904: long (nullable = true)
#  |    |-- 1905: long (nullable = true)
#  |    |-- 1906: long (nullable = true)
#  |    |-- 1907: long (nullable = true)
#  |    |-- 1908: long (nullable = true)
#  |    |-- 1909: long (nullable = true)
#  |    |-- 191: long (nullable = true)
#  |    |-- 1910: long (nullable = true)
#  |    |-- 1911: long (nullable = true)
#  |    |-- 1912: long (nullable = true)
#  |    |-- 1913: long (nullable = true)
#  |    |-- 1914: long (nullable = true)
#  |    |-- 1915: long (nullable = true)
#  |    |-- 1916: long (nullable = true)
#  |    |-- 1917: long (nullable = true)
#  |    |-- 1918: long (nullable = true)
#  |    |-- 1919: long (nullable = true)
#  |    |-- 192: long (nullable = true)
#  |    |-- 1920: long (nullable = true)
#  |    |-- 1921: long (nullable = true)
#  |    |-- 1922: long (nullable = true)
#  |    |-- 1923: long (nullable = true)
#  |    |-- 1924: long (nullable = true)
#  |    |-- 1925: long (nullable = true)
#  |    |-- 1926: long (nullable = true)
#  |    |-- 1927: long (nullable = true)
#  |    |-- 1928: long (nullable = true)
#  |    |-- 1929: long (nullable = true)
#  |    |-- 193: long (nullable = true)
#  |    |-- 1930: long (nullable = true)
#  |    |-- 1931: long (nullable = true)
#  |    |-- 1932: long (nullable = true)
#  |    |-- 1933: long (nullable = true)
#  |    |-- 1934: long (nullable = true)
#  |    |-- 1935: long (nullable = true)
#  |    |-- 1936: long (nullable = true)
#  |    |-- 1937: long (nullable = true)
#  |    |-- 1938: long (nullable = true)
#  |    |-- 1939: long (nullable = true)
#  |    |-- 194: long (nullable = true)
#  |    |-- 1940: long (nullable = true)
#  |    |-- 1941: long (nullable = true)
#  |    |-- 1942: long (nullable = true)
#  |    |-- 1943: long (nullable = true)
#  |    |-- 1944: long (nullable = true)
#  |    |-- 1945: long (nullable = true)
#  |    |-- 1946: long (nullable = true)
#  |    |-- 1947: long (nullable = true)
#  |    |-- 1948: long (nullable = true)
#  |    |-- 1949: long (nullable = true)
#  |    |-- 195: long (nullable = true)
#  |    |-- 1950: long (nullable = true)
#  |    |-- 1951: long (nullable = true)
#  |    |-- 1952: long (nullable = true)
#  |    |-- 1953: long (nullable = true)
#  |    |-- 1954: long (nullable = true)
#  |    |-- 1955: long (nullable = true)
#  |    |-- 1956: long (nullable = true)
#  |    |-- 1957: long (nullable = true)
#  |    |-- 1958: long (nullable = true)
#  |    |-- 1959: long (nullable = true)
#  |    |-- 196: long (nullable = true)
#  |    |-- 1960: long (nullable = true)
#  |    |-- 1961: long (nullable = true)
#  |    |-- 1962: long (nullable = true)
#  |    |-- 1963: long (nullable = true)
#  |    |-- 1964: long (nullable = true)
#  |    |-- 1965: long (nullable = true)
#  |    |-- 1966: long (nullable = true)
#  |    |-- 1967: long (nullable = true)
#  |    |-- 1968: long (nullable = true)
#  |    |-- 1969: long (nullable = true)
#  |    |-- 197: long (nullable = true)
#  |    |-- 1970: long (nullable = true)
#  |    |-- 1971: long (nullable = true)
#  |    |-- 1972: long (nullable = true)
#  |    |-- 1973: long (nullable = true)
#  |    |-- 1974: long (nullable = true)
#  |    |-- 1975: long (nullable = true)
#  |    |-- 1976: long (nullable = true)
#  |    |-- 1977: long (nullable = true)
#  |    |-- 1978: long (nullable = true)
#  |    |-- 1979: long (nullable = true)
#  |    |-- 198: long (nullable = true)
#  |    |-- 1980: long (nullable = true)
#  |    |-- 1981: long (nullable = true)
#  |    |-- 1982: long (nullable = true)
#  |    |-- 1983: long (nullable = true)
#  |    |-- 1984: long (nullable = true)
#  |    |-- 1985: long (nullable = true)
#  |    |-- 1986: long (nullable = true)
#  |    |-- 1987: long (nullable = true)
#  |    |-- 1988: long (nullable = true)
#  |    |-- 1989: long (nullable = true)
#  |    |-- 199: long (nullable = true)
#  |    |-- 1990: long (nullable = true)
#  |    |-- 1991: long (nullable = true)
#  |    |-- 1992: long (nullable = true)
#  |    |-- 1993: long (nullable = true)
#  |    |-- 1994: long (nullable = true)
#  |    |-- 1995: long (nullable = true)
#  |    |-- 1996: long (nullable = true)
#  |    |-- 1997: long (nullable = true)
#  |    |-- 1998: long (nullable = true)
#  |    |-- 1999: long (nullable = true)
#  |    |-- 2: long (nullable = true)
#  |    |-- 20: long (nullable = true)
#  |    |-- 200: long (nullable = true)
#  |    |-- 2000: long (nullable = true)
#  |    |-- 2001: long (nullable = true)
#  |    |-- 2002: long (nullable = true)
#  |    |-- 2003: long (nullable = true)
#  |    |-- 2004: long (nullable = true)
#  |    |-- 2005: long (nullable = true)
#  |    |-- 2006: long (nullable = true)
#  |    |-- 2007: long (nullable = true)
#  |    |-- 2008: long (nullable = true)
#  |    |-- 2009: long (nullable = true)
#  |    |-- 201: long (nullable = true)
#  |    |-- 2010: long (nullable = true)
#  |    |-- 2011: long (nullable = true)
#  |    |-- 2012: long (nullable = true)
#  |    |-- 2013: long (nullable = true)
#  |    |-- 2014: long (nullable = true)
#  |    |-- 2015: long (nullable = true)
#  |    |-- 2016: long (nullable = true)
#  |    |-- 2017: long (nullable = true)
#  |    |-- 2018: long (nullable = true)
#  |    |-- 2019: long (nullable = true)
#  |    |-- 202: long (nullable = true)
#  |    |-- 2020: long (nullable = true)
#  |    |-- 2021: long (nullable = true)
#  |    |-- 2022: long (nullable = true)
#  |    |-- 2023: long (nullable = true)
#  |    |-- 2024: long (nullable = true)
#  |    |-- 2025: long (nullable = true)
#  |    |-- 2026: long (nullable = true)
#  |    |-- 2027: long (nullable = true)
#  |    |-- 2028: long (nullable = true)
#  |    |-- 2029: long (nullable = true)
#  |    |-- 203: long (nullable = true)
#  |    |-- 2030: long (nullable = true)
#  |    |-- 2031: long (nullable = true)
#  |    |-- 2032: long (nullable = true)
#  |    |-- 2033: long (nullable = true)
#  |    |-- 2034: long (nullable = true)
#  |    |-- 2035: long (nullable = true)
#  |    |-- 2036: long (nullable = true)
#  |    |-- 2037: long (nullable = true)
#  |    |-- 2038: long (nullable = true)
#  |    |-- 2039: long (nullable = true)
#  |    |-- 204: long (nullable = true)
#  |    |-- 2040: long (nullable = true)
#  |    |-- 2041: long (nullable = true)
#  |    |-- 2042: long (nullable = true)
#  |    |-- 2043: long (nullable = true)
#  |    |-- 2044: long (nullable = true)
#  |    |-- 2045: long (nullable = true)
#  |    |-- 2046: long (nullable = true)
#  |    |-- 2047: long (nullable = true)
#  |    |-- 2048: long (nullable = true)
#  |    |-- 2049: long (nullable = true)
#  |    |-- 205: long (nullable = true)
#  |    |-- 2050: long (nullable = true)
#  |    |-- 2051: long (nullable = true)
#  |    |-- 2052: long (nullable = true)
#  |    |-- 2053: long (nullable = true)
#  |    |-- 2054: long (nullable = true)
#  |    |-- 2055: long (nullable = true)
#  |    |-- 2056: long (nullable = true)
#  |    |-- 2057: long (nullable = true)
#  |    |-- 2058: long (nullable = true)
#  |    |-- 2059: long (nullable = true)
#  |    |-- 206: long (nullable = true)
#  |    |-- 2060: long (nullable = true)
#  |    |-- 2061: long (nullable = true)
#  |    |-- 2062: long (nullable = true)
#  |    |-- 2063: long (nullable = true)
#  |    |-- 2064: long (nullable = true)
#  |    |-- 2065: long (nullable = true)
#  |    |-- 2066: long (nullable = true)
#  |    |-- 2067: long (nullable = true)
#  |    |-- 2068: long (nullable = true)
#  |    |-- 2069: long (nullable = true)
#  |    |-- 207: long (nullable = true)
#  |    |-- 2070: long (nullable = true)
#  |    |-- 2071: long (nullable = true)
#  |    |-- 2072: long (nullable = true)
#  |    |-- 2073: long (nullable = true)
#  |    |-- 2074: long (nullable = true)
#  |    |-- 2075: long (nullable = true)
#  |    |-- 2076: long (nullable = true)
#  |    |-- 2077: long (nullable = true)
#  |    |-- 2078: long (nullable = true)
#  |    |-- 2079: long (nullable = true)
#  |    |-- 208: long (nullable = true)
#  |    |-- 2080: long (nullable = true)
#  |    |-- 2081: long (nullable = true)
#  |    |-- 2082: long (nullable = true)
#  |    |-- 2083: long (nullable = true)
#  |    |-- 2084: long (nullable = true)
#  |    |-- 2085: long (nullable = true)
#  |    |-- 2086: long (nullable = true)
#  |    |-- 2087: long (nullable = true)
#  |    |-- 2088: long (nullable = true)
#  |    |-- 2089: long (nullable = true)
#  |    |-- 209: long (nullable = true)
#  |    |-- 2090: long (nullable = true)
#  |    |-- 2091: long (nullable = true)
#  |    |-- 2092: long (nullable = true)
#  |    |-- 2093: long (nullable = true)
#  |    |-- 2094: long (nullable = true)
#  |    |-- 2095: long (nullable = true)
#  |    |-- 2096: long (nullable = true)
#  |    |-- 2097: long (nullable = true)
#  |    |-- 2098: long (nullable = true)
#  |    |-- 2099: long (nullable = true)
#  |    |-- 21: long (nullable = true)
#  |    |-- 210: long (nullable = true)
#  |    |-- 2100: long (nullable = true)
#  |    |-- 2101: long (nullable = true)
#  |    |-- 2102: long (nullable = true)
#  |    |-- 2103: long (nullable = true)
#  |    |-- 2104: long (nullable = true)
#  |    |-- 2105: long (nullable = true)
#  |    |-- 2106: long (nullable = true)
# ...
#  |    |-- 8580: long (nullable = true)
#  |    |-- 8581: long (nullable = true)
#  |    |-- 8582: long (nullable = true)
#  |    |-- 8583: long (nullable = true)
#  |    |-- 8584: long (nullable = true)
#  |    |-- 8585: long (nullable = true)
#  |    |-- 8586: long (nullable = true)
#  |    |-- 8587: long (nullable = true)
#  |    |-- 8588: long (nullable = true)
#  |    |-- 8589: long (nullable = true)
#  |    |-- 859: long (nullable = true)
#  |    |-- 8590: long (nullable = true)
#  |    |-- 8591: long (nullable = true)
#  |    |-- 8592: long (nullable = true)
#  |    |-- 8593: long (nullable = true)
#  |    |-- 8594: long (nullable = true)
#  |    |-- 8595: long (nullable = true)
#  |    |-- 8596: long (nullable = true)
#  |    |-- 8597: long (nullable = true)
#  |    |-- 8598: long (nullable = true)
#  |    |-- 8599: long (nullable = true)
#  |    |-- 86: long (nullable = true)
#  |    |-- 860: long (nullable = true)
#  |    |-- 8600: long (nullable = true)
#  |    |-- 8601: long (nullable = true)
#  |    |-- 8602: long (nullable = true)
#  |    |-- 8603: long (nullable = true)
#  |    |-- 8604: long (nullable = true)
#  |    |-- 8605: long (nullable = true)
#  |    |-- 8606: long (nullable = true)
#  |    |-- 8607: long (nullable = true)
#  |    |-- 8608: long (nullable = true)
#  |    |-- 8609: long (nullable = true)
#  |    |-- 861: long (nullable = true)
#  |    |-- 8610: long (nullable = true)
#  |    |-- 8611: long (nullable = true)
#  |    |-- 8612: long (nullable = true)
#  |    |-- 8613: long (nullable = true)
#  |    |-- 8614: long (nullable = true)
#  |    |-- 8615: long (nullable = true)
#  |    |-- 8616: long (nullable = true)
#  |    |-- 8617: long (nullable = true)
#  |    |-- 8618: long (nullable = true)
#  |    |-- 8619: long (nullable = true)
#  |    |-- 862: long (nullable = true)
#  |    |-- 8620: long (nullable = true)
#  |    |-- 8621: long (nullable = true)
#  |    |-- 8622: long (nullable = true)
#  |    |-- 8623: long (nullable = true)
#  |    |-- 8624: long (nullable = true)
#  |    |-- 8625: long (nullable = true)
#  |    |-- 8626: long (nullable = true)
#  |    |-- 8627: long (nullable = true)
#  |    |-- 8628: long (nullable = true)
#  |    |-- 8629: long (nullable = true)
#  |    |-- 863: long (nullable = true)
#  |    |-- 8630: long (nullable = true)
#  |    |-- 8631: long (nullable = true)
#  |    |-- 8632: long (nullable = true)
#  |    |-- 8633: long (nullable = true)
#  |    |-- 8634: long (nullable = true)
#  |    |-- 8635: long (nullable = true)
#  |    |-- 8636: long (nullable = true)
#  |    |-- 8637: long (nullable = true)
#  |    |-- 8638: long (nullable = true)
#  |    |-- 8639: long (nullable = true)
#  |    |-- 864: long (nullable = true)
#  |    |-- 8640: long (nullable = true)
#  |    |-- 8641: long (nullable = true)
#  |    |-- 8642: long (nullable = true)
#  |    |-- 8643: long (nullable = true)
#  |    |-- 8644: long (nullable = true)
#  |    |-- 8645: long (nullable = true)
#  |    |-- 8646: long (nullable = true)
#  |    |-- 8647: long (nullable = true)
#  |    |-- 8648: long (nullable = true)
#  |    |-- 8649: long (nullable = true)
#  |    |-- 865: long (nullable = true)
#  |    |-- 8650: long (nullable = true)
#  |    |-- 8651: long (nullable = true)
#  |    |-- 8652: long (nullable = true)
#  |    |-- 8653: long (nullable = true)
#  |    |-- 8654: long (nullable = true)
#  |    |-- 8655: long (nullable = true)
#  |    |-- 8656: long (nullable = true)
#  |    |-- 8657: long (nullable = true)
#  |    |-- 8658: long (nullable = true)
#  |    |-- 8659: long (nullable = true)
#  |    |-- 866: long (nullable = true)
#  |    |-- 8660: long (nullable = true)
#  |    |-- 8661: long (nullable = true)
#  |    |-- 8662: long (nullable = true)
#  |    |-- 8663: long (nullable = true)
#  |    |-- 8664: long (nullable = true)
#  |    |-- 8665: long (nullable = true)
#  |    |-- 8666: long (nullable = true)
#  |    |-- 8667: long (nullable = true)
#  |    |-- 8668: long (nullable = true)
#  |    |-- 8669: long (nullable = true)
#  |    |-- 867: long (nullable = true)
#  |    |-- 8670: long (nullable = true)
#  |    |-- 8671: long (nullable = true)
#  |    |-- 8672: long (nullable = true)
#  |    |-- 8673: long (nullable = true)
#  |    |-- 8674: long (nullable = true)
#  |    |-- 8675: long (nullable = true)
#  |    |-- 8676: long (nullable = true)
#  |    |-- 8677: long (nullable = true)
#  |    |-- 8678: long (nullable = true)
#  |    |-- 8679: long (nullable = true)
#  |    |-- 868: long (nullable = true)
#  |    |-- 8680: long (nullable = true)
#  |    |-- 8681: long (nullable = true)
#  |    |-- 8682: long (nullable = true)
#  |    |-- 8683: long (nullable = true)
#  |    |-- 8684: long (nullable = true)
#  |    |-- 8685: long (nullable = true)
#  |    |-- 8686: long (nullable = true)
#  |    |-- 8687: long (nullable = true)
#  |    |-- 8688: long (nullable = true)
#  |    |-- 8689: long (nullable = true)
#  |    |-- 869: long (nullable = true)
#  |    |-- 8690: long (nullable = true)
#  |    |-- 8691: long (nullable = true)
#  |    |-- 8692: long (nullable = true)
#  |    |-- 8693: long (nullable = true)
#  |    |-- 8694: long (nullable = true)
#  |    |-- 8695: long (nullable = true)
#  |    |-- 8696: long (nullable = true)
#  |    |-- 8697: long (nullable = true)
#  |    |-- 8698: long (nullable = true)
#  |    |-- 8699: long (nullable = true)
#  |    |-- 87: long (nullable = true)
#  |    |-- 870: long (nullable = true)
#  |    |-- 8700: long (nullable = true)
#  |    |-- 8701: long (nullable = true)
#  |    |-- 8702: long (nullable = true)
#  |    |-- 8703: long (nullable = true)
#  |    |-- 8704: long (nullable = true)
#  |    |-- 8705: long (nullable = true)
#  |    |-- 8706: long (nullable = true)
#  |    |-- 8707: long (nullable = true)
#  |    |-- 8708: long (nullable = true)
#  |    |-- 8709: long (nullable = true)
#  |    |-- 871: long (nullable = true)
#  |    |-- 8710: long (nullable = true)
#  |    |-- 8711: long (nullable = true)
#  |    |-- 8712: long (nullable = true)
#  |    |-- 8713: long (nullable = true)
#  |    |-- 8714: long (nullable = true)
#  |    |-- 8715: long (nullable = true)
#  |    |-- 8716: long (nullable = true)
#  |    |-- 8717: long (nullable = true)
#  |    |-- 8718: long (nullable = true)
#  |    |-- 8719: long (nullable = true)
#  |    |-- 872: long (nullable = true)
#  |    |-- 8720: long (nullable = true)
#  |    |-- 8721: long (nullable = true)
#  |    |-- 8722: long (nullable = true)
#  |    |-- 8723: long (nullable = true)
#  |    |-- 8724: long (nullable = true)
#  |    |-- 8725: long (nullable = true)
#  |    |-- 8726: long (nullable = true)
#  |    |-- 8727: long (nullable = true)
#  |    |-- 8728: long (nullable = true)
#  |    |-- 8729: long (nullable = true)
#  |    |-- 873: long (nullable = true)
#  |    |-- 8730: long (nullable = true)
#  |    |-- 8731: long (nullable = true)
#  |    |-- 8732: long (nullable = true)
#  |    |-- 8733: long (nullable = true)
#  |    |-- 8734: long (nullable = true)
#  |    |-- 8735: long (nullable = true)
#  |    |-- 8736: long (nullable = true)
#  |    |-- 8737: long (nullable = true)
#  |    |-- 8738: long (nullable = true)
#  |    |-- 8739: long (nullable = true)
#  |    |-- 874: long (nullable = true)
#  |    |-- 8740: long (nullable = true)
#  |    |-- 8741: long (nullable = true)
#  |    |-- 8742: long (nullable = true)
#  |    |-- 8743: long (nullable = true)
#  |    |-- 8744: long (nullable = true)
#  |    |-- 8745: long (nullable = true)
#  |    |-- 8746: long (nullable = true)
#  |    |-- 8747: long (nullable = true)
#  |    |-- 8748: long (nullable = true)
#  |    |-- 8749: long (nullable = true)
#  |    |-- 875: long (nullable = true)
#  |    |-- 8750: long (nullable = true)
#  |    |-- 8751: long (nullable = true)
#  |    |-- 8752: long (nullable = true)
#  |    |-- 8753: long (nullable = true)
#  |    |-- 8754: long (nullable = true)
#  |    |-- 8755: long (nullable = true)
#  |    |-- 8756: long (nullable = true)
#  |    |-- 8757: long (nullable = true)
#  |    |-- 8758: long (nullable = true)
#  |    |-- 8759: long (nullable = true)
#  |    |-- 876: long (nullable = true)
#  |    |-- 8760: long (nullable = true)
#  |    |-- 8761: long (nullable = true)
#  |    |-- 8762: long (nullable = true)
#  |    |-- 8763: long (nullable = true)
#  |    |-- 8764: long (nullable = true)
#  |    |-- 8765: long (nullable = true)
#  |    |-- 8766: long (nullable = true)
#  |    |-- 8767: long (nullable = true)
#  |    |-- 8768: long (nullable = true)
#  |    |-- 8769: long (nullable = true)
#  |    |-- 877: long (nullable = true)
#  |    |-- 8770: long (nullable = true)
#  |    |-- 8771: long (nullable = true)
#  |    |-- 8772: long (nullable = true)
#  |    |-- 8773: long (nullable = true)
#  |    |-- 8774: long (nullable = true)
#  |    |-- 8775: long (nullable = true)
#  |    |-- 8776: long (nullable = true)
#  |    |-- 8777: long (nullable = true)
#  |    |-- 8778: long (nullable = true)
#  |    |-- 8779: long (nullable = true)
#  |    |-- 878: long (nullable = true)
#  |    |-- 8780: long (nullable = true)
#  |    |-- 8781: long (nullable = true)
#  |    |-- 8782: long (nullable = true)
#  |    |-- 8783: long (nullable = true)
#  |    |-- 8784: long (nullable = true)
#  |    |-- 8785: long (nullable = true)
#  |    |-- 8786: long (nullable = true)
#  |    |-- 8787: long (nullable = true)
#  |    |-- 8788: long (nullable = true)
#  |    |-- 8789: long (nullable = true)
#  |    |-- 879: long (nullable = true)
#  |    |-- 8790: long (nullable = true)
#  |    |-- 8791: long (nullable = true)
#  |    |-- 8792: long (nullable = true)
#  |    |-- 8793: long (nullable = true)
#  |    |-- 8794: long (nullable = true)
#  |    |-- 8795: long (nullable = true)
#  |    |-- 8796: long (nullable = true)
#  |    |-- 8797: long (nullable = true)
#  |    |-- 8798: long (nullable = true)
#  |    |-- 8799: long (nullable = true)
#  |    |-- 88: long (nullable = true)
#  |    |-- 880: long (nullable = true)
#  |    |-- 8800: long (nullable = true)
#  |    |-- 8801: long (nullable = true)
#  |    |-- 8802: long (nullable = true)
#  |    |-- 8803: long (nullable = true)
#  |    |-- 8804: long (nullable = true)
#  |    |-- 8805: long (nullable = true)
#  |    |-- 8806: long (nullable = true)
#  |    |-- 8807: long (nullable = true)
#  |    |-- 8808: long (nullable = true)
#  |    |-- 8809: long (nullable = true)
#  |    |-- 881: long (nullable = true)
#  |    |-- 8810: long (nullable = true)
#  |    |-- 8811: long (nullable = true)
#  |    |-- 8812: long (nullable = true)
#  |    |-- 8813: long (nullable = true)
#  |    |-- 8814: long (nullable = true)
#  |    |-- 8815: long (nullable = true)
#  |    |-- 8816: long (nullable = true)
#  |    |-- 8817: long (nullable = true)
#  |    |-- 8818: long (nullable = true)
#  |    |-- 8819: long (nullable = true)
#  |    |-- 882: long (nullable = true)
#  |    |-- 8820: long (nullable = true)
#  |    |-- 8821: long (nullable = true)
#  |    |-- 8822: long (nullable = true)
#  |    |-- 8823: long (nullable = true)
#  |    |-- 8824: long (nullable = true)
#  |    |-- 8825: long (nullable = true)
#  |    |-- 8826: long (nullable = true)
#  |    |-- 8827: long (nullable = true)
#  |    |-- 8828: long (nullable = true)
#  |    |-- 8829: long (nullable = true)
#  |    |-- 883: long (nullable = true)
#  |    |-- 8830: long (nullable = true)
#  |    |-- 8831: long (nullable = true)
#  |    |-- 8832: long (nullable = true)
#  |    |-- 8833: long (nullable = true)
#  |    |-- 8834: long (nullable = true)
#  |    |-- 8835: long (nullable = true)
#  |    |-- 8836: long (nullable = true)
#  |    |-- 8837: long (nullable = true)
#  |    |-- 884: long (nullable = true)
#  |    |-- 885: long (nullable = true)
#  |    |-- 886: long (nullable = true)
#  |    |-- 887: long (nullable = true)
#  |    |-- 888: long (nullable = true)
#  |    |-- 889: long (nullable = true)
#  |    |-- 89: long (nullable = true)
#  |    |-- 890: long (nullable = true)
#  |    |-- 891: long (nullable = true)
#  |    |-- 892: long (nullable = true)
#  |    |-- 893: long (nullable = true)
#  |    |-- 894: long (nullable = true)
#  |    |-- 895: long (nullable = true)
#  |    |-- 896: long (nullable = true)
#  |    |-- 897: long (nullable = true)
#  |    |-- 898: long (nullable = true)
#  |    |-- 899: long (nullable = true)
#  |    |-- 9: long (nullable = true)
#  |    |-- 90: long (nullable = true)
#  |    |-- 900: long (nullable = true)
#  |    |-- 901: long (nullable = true)
#  |    |-- 902: long (nullable = true)
#  |    |-- 903: long (nullable = true)
#  |    |-- 904: long (nullable = true)
#  |    |-- 905: long (nullable = true)
#  |    |-- 906: long (nullable = true)
#  |    |-- 907: long (nullable = true)
#  |    |-- 908: long (nullable = true)
#  |    |-- 909: long (nullable = true)
#  |    |-- 91: long (nullable = true)
#  |    |-- 910: long (nullable = true)
#  |    |-- 911: long (nullable = true)
#  |    |-- 912: long (nullable = true)
#  |    |-- 913: long (nullable = true)
#  |    |-- 914: long (nullable = true)
#  |    |-- 915: long (nullable = true)
#  |    |-- 916: long (nullable = true)
#  |    |-- 917: long (nullable = true)
#  |    |-- 918: long (nullable = true)
#  |    |-- 919: long (nullable = true)
#  |    |-- 92: long (nullable = true)
#  |    |-- 920: long (nullable = true)
#  |    |-- 921: long (nullable = true)
#  |    |-- 922: long (nullable = true)
#  |    |-- 923: long (nullable = true)
#  |    |-- 924: long (nullable = true)
#  |    |-- 925: long (nullable = true)
#  |    |-- 926: long (nullable = true)
#  |    |-- 927: long (nullable = true)
#  |    |-- 928: long (nullable = true)
#  |    |-- 929: long (nullable = true)
#  |    |-- 93: long (nullable = true)
#  |    |-- 930: long (nullable = true)
#  |    |-- 931: long (nullable = true)
#  |    |-- 932: long (nullable = true)
#  |    |-- 933: long (nullable = true)
#  |    |-- 934: long (nullable = true)
#  |    |-- 935: long (nullable = true)
#  |    |-- 936: long (nullable = true)
#  |    |-- 937: long (nullable = true)
#  |    |-- 938: long (nullable = true)
#  |    |-- 939: long (nullable = true)
#  |    |-- 94: long (nullable = true)
#  |    |-- 940: long (nullable = true)
#  |    |-- 941: long (nullable = true)
#  |    |-- 942: long (nullable = true)
#  |    |-- 943: long (nullable = true)
#  |    |-- 944: long (nullable = true)
#  |    |-- 945: long (nullable = true)
#  |    |-- 946: long (nullable = true)
#  |    |-- 947: long (nullable = true)
#  |    |-- 948: long (nullable = true)
#  |    |-- 949: long (nullable = true)
#  |    |-- 95: long (nullable = true)
#  |    |-- 950: long (nullable = true)
#  |    |-- 951: long (nullable = true)
#  |    |-- 952: long (nullable = true)
#  |    |-- 953: long (nullable = true)
#  |    |-- 954: long (nullable = true)
#  |    |-- 955: long (nullable = true)
#  |    |-- 956: long (nullable = true)
#  |    |-- 957: long (nullable = true)
#  |    |-- 958: long (nullable = true)
#  |    |-- 959: long (nullable = true)
#  |    |-- 96: long (nullable = true)
#  |    |-- 960: long (nullable = true)
#  |    |-- 961: long (nullable = true)
#  |    |-- 962: long (nullable = true)
#  |    |-- 963: long (nullable = true)
#  |    |-- 964: long (nullable = true)
#  |    |-- 965: long (nullable = true)
#  |    |-- 966: long (nullable = true)
#  |    |-- 967: long (nullable = true)
#  |    |-- 968: long (nullable = true)
#  |    |-- 969: long (nullable = true)
#  |    |-- 97: long (nullable = true)
#  |    |-- 970: long (nullable = true)
#  |    |-- 971: long (nullable = true)
#  |    |-- 972: long (nullable = true)
#  |    |-- 973: long (nullable = true)
#  |    |-- 974: long (nullable = true)
#  |    |-- 975: long (nullable = true)
#  |    |-- 976: long (nullable = true)
#  |    |-- 977: long (nullable = true)
#  |    |-- 978: long (nullable = true)
#  |    |-- 979: long (nullable = true)
#  |    |-- 98: long (nullable = true)
#  |    |-- 980: long (nullable = true)
#  |    |-- 981: long (nullable = true)
#  |    |-- 982: long (nullable = true)
#  |    |-- 983: long (nullable = true)
#  |    |-- 984: long (nullable = true)
#  |    |-- 985: long (nullable = true)
#  |    |-- 986: long (nullable = true)
#  |    |-- 987: long (nullable = true)
#  |    |-- 988: long (nullable = true)
#  |    |-- 989: long (nullable = true)
#  |    |-- 99: long (nullable = true)
#  |    |-- 990: long (nullable = true)
#  |    |-- 991: long (nullable = true)
#  |    |-- 992: long (nullable = true)
#  |    |-- 993: long (nullable = true)
#  |    |-- 994: long (nullable = true)
#  |    |-- 995: long (nullable = true)
#  |    |-- 996: long (nullable = true)
#  |    |-- 997: long (nullable = true)
#  |    |-- 998: long (nullable = true)
#  |    |-- 999: long (nullable = true)

# %% [markdown]
# O installments_sample apresenta as linha em formato de estrutura, dificultando a visuallização dos valores e do schema. Para poder trabalhar com esse dataframe irei dsaclpar os dados de cada elemento da estrutura e gerar um novo dataframe com os dados em diferentes linhas.

# %%
from pyspark.sql import functions as F

# %%
#coverter as culunas de struct para array
installments_sample = installments_sample.select(
    F.array(F.expr("loan_id.*")).alias("loan_id"),
    F.array(F.expr("due_date.*")).alias("due_date"),
    F.array(F.expr("installment_value.*")).alias("installment_value"),
    F.array(F.expr("number.*")).alias("number")
)

# %%
installments_sample.printSchema()
# Out:
# root
#  |-- loan_id: array (nullable = false)
#  |    |-- element: long (containsNull = true)
#  |-- due_date: array (nullable = false)
#  |    |-- element: long (containsNull = true)
#  |-- installment_value: array (nullable = false)
#  |    |-- element: double (containsNull = true)
#  |-- number: array (nullable = false)
#  |    |-- element: long (containsNull = true)

# %%
#novo dataframe com acess direto aos dados
installments_sample = installments_sample.withColumn("installments", F.explode(F.arrays_zip("loan_id", "due_date","installment_value","number")))\
    .select("installments.loan_id", "installments.due_date","installments.installment_value","installments.number")

# %%
installments_sample.printSchema()
# Out:
# root
#  |-- loan_id: long (nullable = true)
#  |-- due_date: long (nullable = true)
#  |-- installment_value: double (nullable = true)
#  |-- number: long (nullable = true)

# %%
installments_sample.show(truncate=False)
# Out:
# +-------+-------------+-----------------+------+
# |loan_id|due_date     |installment_value|number|
# +-------+-------------+-----------------+------+
# |291    |1497225600000|547.92           |1     |
# |291    |1499817600000|547.92           |2     |
# |291    |1515715200000|547.92           |8     |
# |703    |1513900800000|196.36           |6     |
# |150    |1517443200000|1033.75          |9     |
# |150    |1520121600000|1033.75          |10    |
# |150    |1522540800000|1033.75          |11    |
# |150    |1525219200000|1033.75          |12    |
# |146    |1496275200000|373.74           |1     |
# |146    |1498953600000|373.74           |2     |
# |146    |1501545600000|373.74           |3     |
# |146    |1504224000000|373.74           |4     |
# |146    |1506902400000|373.74           |5     |
# |146    |1509494400000|373.74           |6     |
# |703    |1516579200000|196.36           |7     |
# |146    |1512172800000|373.74           |7     |
# |146    |1514764800000|373.74           |8     |
# |146    |1517443200000|373.74           |9     |
# |146    |1520121600000|373.74           |10    |
# |146    |1522540800000|373.74           |11    |
# +-------+-------------+-----------------+------+
# only showing top 20 rows

# %%
print("Total de valores nulos por coluna:")
for col in installments_sample.columns:
  print(" {}={}".format(col, installments_sample.filter(installments_sample[col].isNull() ).count()) )
# Out:
# Total de valores nulos por coluna:
#  loan_id=0
#  due_date=0
#  installment_value=0
#  number=0

# %%
installments_sample.count()
# Out:
# 8838

# %%
installments_sample.select("loan_id").distinct().count()
# Out:
# 775

# %% [markdown]
# Agora podemos verificar que installments_sample apresenta informações como identificador do emprestimo, data de vencimento da parcela, número e valor da parcela . Possui 8838 registros e não possui valores nulos. Esses registros são referentes a um total de 755 emprestimos realizados, tal como payments_sample.

# %%
idsPay = payments_sample.select("loan_id").sort("loan_id").distinct().collect()

# %%
idsInst = installments_sample.select("loan_id").sort("loan_id").distinct().collect()

# %%
idsLoan = loans_sample.select("loan_id").sort("loan_id").distinct().collect()

# %%
idsPay = [ x.__getitem__("loan_id") for x in idsPay]

# %%
idsLoan = [ x.__getitem__("loan_id") for x in idsLoan]

# %%
idsInst = [ x.__getitem__("loan_id") for x in idsInst]

# %%
set(idsLoan).difference(set(idsPay))
# Out:
# {2, 96, 127, 296, 369, 383, 389, 440, 455, 507, 542, 692, 785}

# %%
set(idsLoan).difference(set(idsInst))
# Out:
# {2, 96, 127, 296, 369, 383, 389, 440, 455, 507, 542, 692, 785}

# %%
set(idsPay).difference(set(idsInst))
# Out:
# set()

# %% [markdown]
# como pode se verificar acima payments_sample e installments_sample possuem os mesmo loan_id e loans_sample possui os loan_id {2, 96, 127, 296, 369, 383, 389, 440, 455, 507, 542, 692, 785}. Uma vez que a próxima etapa será feito o join dos 3 dataframes pela coluna loan_id esses loan_id excedentes serão descartados.

# %% [markdown]
# ## Criando loan_documents

# %% [markdown]
# Para criar o novo dataframe loan_documents conforme a especificação do teste irei realizar algumas operações de agrupamento e agregação nos dataframes installments_sample e payments_sample para então junta-los ao loans_sample.

# %%
from pyspark.sql.types import IntegerType,StringType

# %%
#agrupando valores por loan_id e agregando number e due_date no MAP<INT,STRING>
df_installments = installments_sample.groupBy("loan_id").\
    agg(F.collect_list(F.create_map(F.col("number").cast(IntegerType()),
    F.col("due_date").cast(StringType()))).alias("installments"))

# %%
df_installments.show(5,truncate=False)
# Out:
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |loan_id|installments                                                                                                                                                                                                                                                               |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |26     |[[1 -> 1498089600000], [2 -> 1500681600000], [3 -> 1503360000000], [4 -> 1506038400000], [5 -> 1508630400000], [6 -> 1511308800000], [7 -> 1513900800000], [8 -> 1516579200000], [9 -> 1519257600000], [10 -> 1521676800000], [11 -> 1524355200000], [12 -> 1526947200000]]|
# |43     |[[1 -> 1498089600000], [2 -> 1500681600000], [3 -> 1503360000000], [4 -> 1506038400000], [5 -> 1508630400000], [6 -> 1511308800000], [7 -> 1513900800000], [8 -> 1516579200000], [9 -> 1519257600000], [10 -> 1521676800000], [11 -> 1524355200000], [12 -> 1526947200000]]|
# |777    |[[1 -> 1500681600000], [2 -> 1503360000000], [3 -> 1506038400000], [4 -> 1508630400000], [5 -> 1511308800000], [6 -> 1513900800000], [7 -> 1516579200000], [8 -> 1519257600000], [9 -> 1521676800000], [10 -> 1524355200000], [11 -> 1526947200000], [12 -> 1529625600000]]|
# |465    |[[1 -> 1498953600000], [2 -> 1501545600000], [3 -> 1504224000000], [4 -> 1506902400000], [5 -> 1509494400000], [6 -> 1512172800000], [11 -> 1525219200000], [12 -> 1527811200000], [10 -> 1522540800000], [7 -> 1514764800000], [8 -> 1517443200000], [9 -> 1520121600000]]|
# |277    |[[1 -> 1498089600000], [2 -> 1500681600000], [3 -> 1503360000000], [4 -> 1506038400000], [5 -> 1508630400000], [6 -> 1511308800000], [7 -> 1513900800000], [8 -> 1516579200000], [9 -> 1519257600000], [10 -> 1521676800000], [11 -> 1524355200000], [12 -> 1526947200000]]|
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
df_installments.printSchema()
# Out:
# root
#  |-- loan_id: long (nullable = true)
#  |-- installments: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: integer
#  |    |    |-- value: string (valueContainsNull = true)

# %%
#escrevendo resultado do agrupamento e agregação em um arquivo parquet auxiliar
df_installments.write.parquet("temp/install_group.parquet")

# %%
#agrupando valores por loan_id e agregando as demais colunas em um array de struct
df_payments = payments_sample.groupBy("loan_id").\
    agg(F.collect_list(F.struct(F.col("payment_id").alias("id"),
    F.col("payment_date"),F.col("payment_method").alias("method"),F.col("paid_amount").alias("amount"))).alias("payments"))

# %%
df_payments.printSchema()
# Out:
# root
#  |-- loan_id: long (nullable = true)
#  |-- payments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- payment_date: date (nullable = true)
#  |    |    |-- method: string (nullable = true)
#  |    |    |-- amount: double (nullable = true)

# %%
#escrevendo resultado do agrupamento e agregação em um arquivo parquet auxiliar
df_payments.write.parquet("temp/payments_group.parquet")

# %%
df_payments.show(2,truncate=False)
# Out:
# +-------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |loan_id|payments                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +-------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |26     |[[ca0856b9-464e-4e4d-913a-e649d5c1379b, 2017-06-12, creditcard, 634.99], [837d1626-d070-44e5-b5d9-722ea983d11b, 2017-07-15, boleto, 634.99], [8d1979b1-2219-428d-bb14-1f28ba759c77, 2017-08-15, boleto, 634.99], [09511300-1579-415f-9ebb-3bb4f3aefc10, 2017-09-15, creditcard, 634.99], [1fcf1a21-6418-40e0-9b07-ea5d8f7269e3, 2017-11-15, ted, 634.99], [f9a05fee-5df3-4a29-839a-b1d26f821c17, 2017-12-15, creditcard, 634.99], [d1489602-4f23-463e-9f87-c37ea10d2006, 2018-01-15, creditcard, 634.99], [ef7af21b-1293-4cc8-9cc5-0d8eb7e76d2e, 2018-02-15, boleto, 634.99], [9cf9e502-1e58-41ff-bc90-bb4e0fff2d89, 2018-03-15, creditcard, 634.99], [09ce4e5a-b754-4482-b5fe-fe3fe4601f1e, 2018-05-15, ted, 634.99]]|
# |43     |[[68cc5108-092c-4364-bcc2-424236181e07, 2017-06-15, creditcard, 258.69], [aba4e3e2-eb71-4bfe-9537-ecfb8384ec25, 2017-07-15, creditcard, 258.69], [e26c7a27-f664-41e5-a3b1-a01b296508b1, 2017-09-15, creditcard, 258.69], [92674d4f-f674-4a0b-8bc0-0d8e4648fef3, 2017-10-15, ted, 258.69], [37361c35-4961-4a4c-8931-0603d7445446, 2017-12-15, boleto, 258.69], [7136e5eb-2e01-4d36-a394-c85bc55af1aa, 2018-01-15, creditcard, 258.69], [48bcef1d-6343-4158-9d42-13d39f86baa6, 2018-04-15, boleto, 258.69]]                                                                                                                                                                                                             |
# +-------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 2 rows

# %% [markdown]
# Nesse momento o kernel do jupyter é reiniciado e teste continua carregando os arquivos parquets escritos anteriormente.

# %%
#carregando dataframe com as informaçoes de pagamento agregadas
payments = spark.read.parquet("payments_group.parquet")

# %%
#carregando dataframe com as informaçoes dos vencimentos das parcelas
installments = spark.read.parquet("install_group.parquet")

# %%
#recarregando loan_sample
loans_sample = spark.read.csv("input/loans_sample.csv",header=True, inferSchema=True)

# %%
#join dos 3 dataframes por loan_id
loan_doc = loans_sample.join(installments, ["loan_id"]).join(payments,["loan_id"])

# %%
#schema do dataframe resultado do join
loan_doc.printSchema()
# Out:
# root
#  |-- loan_id: integer (nullable = true)
#  |-- _c0: integer (nullable = true)
#  |-- period: integer (nullable = true)
#  |-- accepted_at: timestamp (nullable = true)
#  |-- payday: integer (nullable = true)
#  |-- interest_rate: double (nullable = true)
#  |-- installments: array (nullable = true)
#  |    |-- element: map (containsNull = true)
#  |    |    |-- key: integer
#  |    |    |-- value: string (valueContainsNull = true)
#  |-- payments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- payment_date: date (nullable = true)
#  |    |    |-- method: string (nullable = true)
#  |    |    |-- amount: double (nullable = true)

# %%
#escrevendo resultado do join em um arquivo parquet auxiliar
loan_doc.write.parquet("temp/loan_doc.parquet")

# %%
#exemplo de linha
loan_doc.head()
# Out:
# Row(loan_id=53, _c0=53, period=12, accepted_at=datetime.datetime(2017, 5, 23, 8, 48, 32, 318000), payday=25, interest_rate=7.55, installments=[{1: u'1498953600000'}, {2: u'1501545600000'}, {3: u'1504224000000'}, {4: u'1506902400000'}, {6: u'1512172800000'}, {9: u'1520121600000'}, {11: u'1525219200000'}, {12: u'1527811200000'}, {10: u'1522540800000'}, {7: u'1514764800000'}, {8: u'1517443200000'}, {5: u'1509494400000'}], payments=[Row(id=u'40018e79-f4da-40cb-a045-2997f22487e3', payment_date=datetime.date(2017, 6, 15), method=u'creditcard', amount=292.36), Row(id=u'a7c87c2a-98f0-4c71-94a3-da5013a658d5', payment_date=datetime.date(2017, 7, 30), method=u'ted', amount=292.36), Row(id=u'177bf69e-f82a-4679-9385-13607366c160', payment_date=datetime.date(2017, 9, 3), method=u'ted', amount=337.36), Row(id=u'71e207b2-fcd4-4b25-9dea-e246244d2957', payment_date=datetime.date(2017, 9, 21), method=u'ted', amount=292.36), Row(id=u'72e63027-5aef-43c5-90d0-6fa7509d3af1', payment_date=datetime.date(2017, 12, 8), method=u'creditcard', amount=304.36), Row(id=u'a65d3bc9-c61d-4ee3-8991-11e3210af0ef', payment_date=datetime.date(2018, 3, 3), method=u'ted', amount=292.36), Row(id=u'ceea80fd-83e4-44ce-b138-0ad29f9a872e', payment_date=datetime.date(2018, 4, 24), method=u'ted', amount=292.36), Row(id=u'64920701-b994-47a1-9ad9-0c4b857c0688', payment_date=datetime.date(2018, 5, 10), method=u'creditcard', amount=292.36), Row(id=u'7c772ca5-fa3c-46a3-993a-ab3e69f4ab17', payment_date=datetime.date(2018, 3, 24), method=u'ted', amount=292.36), Row(id=u'5177699f-cf8d-49b8-84e4-4b062b3c4d75', payment_date=datetime.date(2017, 12, 22), method=u'ted', amount=292.36), Row(id=u'6266b857-a29e-4e98-a786-c7b106a495c4', payment_date=datetime.date(2018, 2, 5), method=u'ted', amount=297.36), Row(id=u'64714087-4deb-4dcc-a696-213807584b50', payment_date=datetime.date(2017, 10, 17), method=u'creditcard', amount=292.36)])

# %%
#carregando parquet com o join dos 3 dataframes
loan = spark.read.parquet("loan_doc.parquet")

# %%
#validando número de linhas
loan.select("loan_id").count()
# Out:
# 775

# %% [markdown]
# o número de loan_id do arquivo parquet auxiliar é igual ao número de loan_id dos dataframes de entrada

# %%
# função que irá ler cada linha dataframe juntado 
# e gerar uma nova linha com os valores da forma descrita na especificação de loan_documents
def parser(line):
    from pyspark.sql import Row
    from collections import defaultdict
    from datetime import datetime
    
    row = defaultdict() # dicionario que ira armazenar os elementos da nova linha que será retornada
    
    #campos que não serão transformados
    row["loan_id"] = line["loan_id"]
    row["period"] = line["period"]
    row["payday"] = line["payday"]
    row["accepted_at"] = line["accepted_at"]
    row["interest_rate"] = line["interest_rate"]
    
    #criar instalments no formato Map
    instDict = defaultdict() 
    vencimentos= [] # lista com as datas de vencimentos das parcelas
    for install in line["installments"]:
        date = datetime.fromtimestamp(long(install.values()[0])/1000.0) #convert timestamp milisegundos para datetime
        vencimentos.append(date) #insere data de vencimento em datetime
        instDict[install.keys()[0]] = date.strftime("%Y-%m-%d") #converte para string formato ano-mes-dia
    row["installments"] = instDict
    
    

        
    vencimentos.sort() #ordena as datas de vencimento
    
    #converter payment_date para string formato ano-mes-dia e pegar datas de pagamentos a serem usadas em metrics
    row["payments"] = line["payments"]
    p = [] 
    pagamentos = [] # lista das datas de pagamentos
    for pay in row["payments"]:
        pagamentos.append(pay["payment_date"])
        p.append(Row(id=pay["id"],
      payment_date=pay["payment_date"].strftime("%Y-%m-%d"),method=pay["method"],amount=pay["amount"])
        )
    row["payments"] = p
    
    #metrics
    pagamentos.sort() #ordena data de pagamentops
    days = (datetime.now() - line["accepted_at"] ).days # total de dias da data de aceitação até hoje
    latency = [False]*days #inicializa array de tamanho days latency com false
    over30 = [False]*days #inicializa array de tamanho days over30 com false
    
    
   
    
    venc_size = len(vencimentos) #total de datas de vencimento
    pag_size = len(pagamentos) #total de datas de pagamento
    
    #Assumindo que não há mais pagamentos do que numero de parelas, caso contrario lança exceção
    if(pag_size > venc_size ):
        raise ValueError('Numero de pagamentos maior que o de parcelas')
        
    # verifica se há data de pagamento maior que a data atual
#     if(datetime.now() - datetime.combine(pagamentos[-1], datetime.min.time())).days < 0:
#         raise ValueError('data de pagamento maior que hoje( {}): loan_id = {}'\
#                          .format(pagamentos[-1].strftime("%Y-%m-%d"),line["loan_id"], ))
        
    
    for v,p in zip(vencimentos,pagamentos): #faz um par das datas de vencimento e pagamento ordenadas
        venc_index = (v -line["accepted_at"] ).days #posicao da data de vencimento no array
        #posicao da data de pagamento no array
        pg = datetime.combine(p, datetime.min.time())
        pag_index = (pg - line["accepted_at"] ).days
        
        pag_index = min(pag_index,days) #tratamento para data de pagamentos maiores que a data atual
        
        for index in range(venc_index,pag_index):# marca como true do dia posterior a data de vencimento até o dia anterior a data de pagamento
            latency[index]=True
            
        for index in range(venc_index+30,pag_index): #marca como true a apartir de 30 dias da data de vencimento até a data de pagamento
            over30[index]=True
    
    #Nos casos que o numero de pagamentos é inferior ao total de parcelas existentes 
    # preenche do dia da primeira parcela não até o dia atual como true
    if( venc_size > pag_size):
        venc_index = (vencimentos[pag_size] - line["accepted_at"]).days
        for index in range(venc_index,days):
            latency[index]=True
        for index in range(venc_index+30,days):
            over30[index]=True
            
    row["metrics"] = Row(latency=latency,over30=over30)
            
    return Row(**row)

# %%
#faz parser das linhas e adiciona metrics
loan_parsed = loan.rdd.map(parser).toDF()

# %%
loan_parsed.printSchema()
# Out:
# root
#  |-- accepted_at: timestamp (nullable = true)
#  |-- installments: map (nullable = true)
#  |    |-- key: long
#  |    |-- value: string (valueContainsNull = true)
#  |-- interest_rate: double (nullable = true)
#  |-- loan_id: long (nullable = true)
#  |-- metrics: struct (nullable = true)
#  |    |-- latency: array (nullable = true)
#  |    |    |-- element: boolean (containsNull = true)
#  |    |-- over30: array (nullable = true)
#  |    |    |-- element: boolean (containsNull = true)
#  |-- payday: long (nullable = true)
#  |-- payments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- amount: double (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- method: string (nullable = true)
#  |    |    |-- payment_date: string (nullable = true)
#  |-- period: long (nullable = true)

# %%
loan_parsed.show()
# Out:
# +--------------------+--------------------+-------------+-------+--------------------+------+--------------------+------+
# |         accepted_at|        installments|interest_rate|loan_id|             metrics|payday|            payments|period|
# +--------------------+--------------------+-------------+-------+--------------------+------+--------------------+------+
# |2017-05-23 08:48:...|[1 -> 2017-07-01,...|         7.55|     53|[[false, false, f...|    25|[[292.36, 40018e7...|    12|
# |2017-04-30 18:46:...|[1 -> 2017-06-11,...|         7.49|    171|[[false, false, f...|     5|[[439.84, 2680a71...|     9|
# |2017-05-11 20:11:...|[1 -> 2017-06-21,...|         7.55|    312|[[false, false, f...|    15|[[582.65, 896568e...|    12|
# |2017-05-24 04:35:...|[1 -> 2017-07-11,...|         3.12|    466|[[false, false, f...|     5|[[916.97, b395237...|    12|
# |2017-06-07 18:29:...|[1 -> 2017-07-11,...|         3.12|    747|[[false, false, f...|     5|[[517.13, 053a125...|    12|
# |2017-06-06 10:57:...|[1 -> 2017-07-11,...|         7.55|    654|[[false, false, f...|     5|[[464.8, d255811c...|    12|
# |2017-06-09 14:07:...|[1 -> 2017-07-21,...|         7.55|    723|[[false, false, f...|    15|[[282.54, dd89d06...|    12|
# |2017-06-07 15:08:...|[1 -> 2017-07-01,...|         7.55|    734|[[false, false, f...|    25|[[688.14, 5e2ab4d...|    12|
# |2017-06-07 15:52:...|[1 -> 2017-07-01,...|         7.55|    742|[[false, false, f...|    25|[[331.66, d180f3a...|    12|
# |2017-05-09 04:31:...|[1 -> 2017-06-21,...|         7.55|    277|[[false, false, f...|    15|[[390.61, 3cc5691...|    12|
# |2017-05-06 22:53:...|[1 -> 2017-05-31,...|         7.55|    287|[[false, false, f...|    25|[[332.44, 4f33b82...|    12|
# |2017-06-07 01:24:...|[1 -> 2017-07-01,...|         7.55|    657|[[false, false, f...|    25|[[262.02, 3f58e61...|    12|
# |2017-06-07 18:03:...|[1 -> 2017-07-11,...|         7.55|    733|[[false, false, f...|     5|[[546.03, b1878cb...|    12|
# |2017-05-16 08:23:...|[1 -> 2017-06-21,...|         7.49|      6|[[false, false, f...|    15|[[304.47, 7d82612...|     9|
# |2017-05-31 20:15:...|[1 -> 2017-07-01,...|         3.12|    619|[[false, false, f...|    25|[[626.78, 03616bf...|    12|
# |2017-06-04 17:14:...|[1 -> 2017-07-21,...|         7.55|    683|[[false, false, f...|    15|[[600.61, e88ec64...|    12|
# |2017-06-07 10:12:...|[1 -> 2017-07-21,...|         7.55|    713|[[false, false, f...|    15|[[407.53, 06192d6...|    12|
# |2017-04-17 11:17:...|[1 -> 2017-05-11,...|         7.55|     72|[[false, false, f...|     5|[[970.25, 9e55261...|    12|
# |2017-04-12 16:18:...|[1 -> 2017-05-21,...|         3.12|     87|[[false, false, f...|    15|[[477.2, ef74112c...|    12|
# |2017-04-26 15:58:...|[1 -> 2017-05-21,...|         3.12|    172|[[false, false, f...|    15|[[363.12, abf7160...|    12|
# +--------------------+--------------------+-------------+-------+--------------------+------+--------------------+------+
# only showing top 20 rows

# %% [markdown]
# Como se pode observar no schema depois do parser ainda é necessário fazer algums conversções de tipo e por em ordem as colunas

# %%
#gerando dataframe loan_documents
from pyspark.sql import functions as F
from pyspark.sql.types import IntegerType,StringType,MapType
loan_documents = loan_parsed.select(F.col("loan_id").cast(IntegerType()),F.col("period").cast(IntegerType()),\
         F.col("accepted_at"),F.col("payday").cast(IntegerType()),F.col("interest_rate"),\
         F.col("installments").cast(MapType(IntegerType(),StringType() )),\
        F.col("payments"),F.col("metrics"))

# %%
#escrevendo loan_documents em um parquet de saida
loan_documents.write.parquet("output/loan_documents.parquet")

# %% [markdown]
# ## Validação

# %%
pagamentos2019 = loan_documents.select(F.explode("payments").alias("payments") )\
    .filter(F.year("payments.payment_date") == 2019)\
    .groupBy(F.month("payments.payment_date").alias("month"),F.year("payments.payment_date").alias("year"))\
    .agg(F.sum("payments.amount").alias("amount")).sort("month")

# %%
#total do valor pago a cada mês de 2019
pagamentos2019.show()
# Out:
# +-----+----+------+
# |month|year|amount|
# +-----+----+------+
# |    1|2019|377.88|
# |    2|2019|377.88|
# |    3|2019|420.88|
# |    4|2019|755.76|
# |    5|2019|770.49|
# |    6|2019|392.61|
# |    8|2019|392.61|
# +-----+----+------+
